# %%
from difeomorfismos_solvers import *
from difeomorfismo import *
import winsound, sys

def beep(sound):
    winsound.PlaySound('%s.wav' % sound, winsound.SND_FILENAME)
init_printing()

# %% [markdown]
# <H3>Difeomorsimos Cuadratico + lineal </H3>
# <H3>$X^{c} = M_{dd}^{c}E^{d}E^{d}$<H3>
# <H3>$Y_{c} = N_{cee}I^{e}I^{e}$</H3>

# %% [markdown]
# # <H3>Defino la dimension que utilizare</H3>

# %%
n=2

# %% [markdown]
# <H3>Estos son las dos coordenadas del difeomorfismo</H3>

# %%
ZE, ZX = set_coordinates(n)

# %% [markdown]
# <H3>Estas son las constates para las ecuaciones del difeomorfismo Cuadratico + lineal</H3>

# %%
import operator
A,c1=set_constants_a(n,'A','s')
D,c2=set_constants_a(n,'D','s')
B,c3=set_constants_axb(n,n,'B',0)
G,c4=set_constants_axb(n,n,'G',0)
C,c5=set_constants_axb(n,n,'C',0)
H,c6=set_constants_axb(n,n,'H',0)
M,c7=set_constants_axbxc(n,n,n,'M','s',operator.ge)
N,c8=set_constants_axbxc(n,n,n,'N','s',operator.ge)
J,c9=set_constants_axbxc00(n,n,n,'J','s')
K,c10=set_constants_axbxc00(n,n,n,'K','s')
P,c11 = set_constants_axbxcxdxe(n,n,n,n,n,'P','s')
Q,c12 = set_constants_axbxcxdxe(n,n,n,n,n,'Q','s')
R,c13 = set_constants_axbxcxdxe(n,n,n,n,n,'R','s')
T,c14 = set_constants_axbxcxdxe(n,n,n,n,n,'T','s')

p,c1=set_constants_axb(n,n,'p','s')

# %%
c = c1 + c2 + c3 + c4 + c5 + c6 + c7 + c8 + c9 + c10 + c11 + c12 + c13 + c14
c = list(filter(lambda a: a != 0, c))

# %%
dc = {}
for x in c:
    dc[x]=1

# %%
dZE = {}
for x in ZE:
    dZE[x]=1

# %%
caiman1 = [
P[0][0][1][0,1],
P[0][0][1][1,0],
P[0][1][0][0,1],
P[0][1][0][1,0],
P[0][1][1][1,1],
]

caiman2 = [
T[0][0][1][0,1],
T[0][0][1][1,0],
T[0][1][0][0,1],
T[0][1][0][1,0],
T[0][1][1][1,1],
]

caiman3 = [
P[1][0][1][0,1],
P[1][0][1][1,0],
P[1][1][0][0,1],
P[1][1][0][1,0],
P[1][1][1][1,1],
]

caiman4 = [
T[1][0][1][0,1],
T[1][0][1][1,0],
T[1][1][0][0,1],
T[1][1][0][1,0],
T[1][1][1][1,1],
]

# %%
caiman = caiman1 + caiman2 + caiman3 + caiman4

# %%
len(caiman1)
# Out:
# 5

# %%
for x in range(0,n):
    for y in range(0,n):
        for z in range(0,n):
            for w in range(0,n):
                for h in range(0,n):
                    if P[x][y][z][w,h] in caiman1:
                        P[x][y][z][w,h] = P[0][0][0][0,0]
                    if T[x][y][z][w,h] in caiman2:
                        T[x][y][z][w,h] = T[0][0][0][0,0]
                    if P[x][y][z][w,h] in caiman3:
                        P[x][y][z][w,h] = P[1][0][0][0,0]
                    if T[x][y][z][w,h] in caiman4:
                        T[x][y][z][w,h] = T[1][0][0][0,0]

# %%
P
# Out:
# ⎡⎡⎡⎡P₁₁₁₁₁  P₁₁₁₁₂⎤, ⎡P₁₁₂₁₁  P₁₁₁₁₁⎤⎤, ⎡⎡P₁₂₁₁₁  P₁₁₁₁₁⎤, ⎡P₁₂₂₁₁  P₁₂₂₁₂⎤⎤⎤,
# ⎢⎢⎢⎢              ⎥  ⎢              ⎥⎥  ⎢⎢              ⎥  ⎢              ⎥⎥⎥
# ⎣⎣⎣⎣P₁₁₁₂₁  P₁₁₁₂₂⎦  ⎣P₁₁₁₁₁  P₁₁₂₂₂⎦⎦  ⎣⎣P₁₁₁₁₁  P₁₂₁₂₂⎦  ⎣P₁₂₂₂₁  P₁₁₁₁₁⎦⎦⎦
#
#  ⎡⎡⎡P₂₁₁₁₁  P₂₁₁₁₂⎤, ⎡P₂₁₂₁₁  P₂₁₁₁₁⎤⎤, ⎡⎡P₂₂₁₁₁  P₂₁₁₁₁⎤, ⎡P₂₂₂₁₁  P₂₂₂₁₂⎤⎤⎤⎤
#  ⎢⎢⎢              ⎥  ⎢              ⎥⎥  ⎢⎢              ⎥  ⎢              ⎥⎥⎥⎥
#  ⎣⎣⎣P₂₁₁₂₁  P₂₁₁₂₂⎦  ⎣P₂₁₁₁₁  P₂₁₂₂₂⎦⎦  ⎣⎣P₂₁₁₁₁  P₂₂₁₂₂⎦  ⎣P₂₂₂₂₁  P₂₁₁₁₁⎦⎦⎦⎦

# %%
T
# Out:
# ⎡⎡⎡⎡T₁₁₁₁₁  T₁₁₁₁₂⎤, ⎡T₁₁₂₁₁  T₁₁₁₁₁⎤⎤, ⎡⎡T₁₂₁₁₁  T₁₁₁₁₁⎤, ⎡T₁₂₂₁₁  T₁₂₂₁₂⎤⎤⎤,
# ⎢⎢⎢⎢              ⎥  ⎢              ⎥⎥  ⎢⎢              ⎥  ⎢              ⎥⎥⎥
# ⎣⎣⎣⎣T₁₁₁₂₁  T₁₁₁₂₂⎦  ⎣T₁₁₁₁₁  T₁₁₂₂₂⎦⎦  ⎣⎣T₁₁₁₁₁  T₁₂₁₂₂⎦  ⎣T₁₂₂₂₁  T₁₁₁₁₁⎦⎦⎦
#
#  ⎡⎡⎡T₂₁₁₁₁  T₂₁₁₁₂⎤, ⎡T₂₁₂₁₁  T₂₁₁₁₁⎤⎤, ⎡⎡T₂₂₁₁₁  T₂₁₁₁₁⎤, ⎡T₂₂₂₁₁  T₂₂₂₁₂⎤⎤⎤⎤
#  ⎢⎢⎢              ⎥  ⎢              ⎥⎥  ⎢⎢              ⎥  ⎢              ⎥⎥⎥⎥
#  ⎣⎣⎣T₂₁₁₂₁  T₂₁₁₂₂⎦  ⎣T₂₁₁₁₁  T₂₁₂₂₂⎦⎦  ⎣⎣T₂₁₁₁₁  T₂₂₁₂₂⎦  ⎣T₂₂₂₂₁  T₂₁₁₁₁⎦⎦⎦⎦

# %%
m = Symbol('m')
n1 = Symbol('n')
r = Symbol('r')
s = Symbol('s')

t = Symbol('t')
w = Symbol('w')
u = Symbol('u')
v = Symbol('v')

cof = [[P],[T],[B],[G]]
#power = [[[m,n1,r,s]],[[m,n1,r,s]]]
power = [[[1,1,1,1]],[[1,1,1,1]]]

# %%
L0 = pow_difeomorphism(cof,n,ZX,ZE,power)
Matrix(L0)
# Out:
# ⎡
# ⎢
# ⎢  2            2            2            2
# ⎢E₁ ⋅P₁₁₁₁₁ + E₁ ⋅P₁₁₁₁₂ + E₁ ⋅P₁₁₁₂₁ + E₁ ⋅P₁₁₁₂₂ + 4⋅E₁⋅E₂⋅P₁₁₁₁₁ + E₁⋅E₂⋅P₁
# ⎢
# ⎢  2            2            2            2
# ⎢E₁ ⋅P₂₁₁₁₁ + E₁ ⋅P₂₁₁₁₂ + E₁ ⋅P₂₁₁₂₁ + E₁ ⋅P₂₁₁₂₂ + 4⋅E₁⋅E₂⋅P₂₁₁₁₁ + E₁⋅E₂⋅P₂
# ⎢
# ⎢  2            2            2            2
# ⎢I₁ ⋅T₁₁₁₁₁ + I₁ ⋅T₁₁₂₁₁ + I₁ ⋅T₁₂₁₁₁ + I₁ ⋅T₁₂₂₁₁ + 4⋅I₁⋅I₂⋅T₁₁₁₁₁ + I₁⋅I₂⋅T₁
# ⎢
# ⎢  2            2            2            2
# ⎣I₁ ⋅T₂₁₁₁₁ + I₁ ⋅T₂₁₂₁₁ + I₁ ⋅T₂₂₁₁₁ + I₁ ⋅T₂₂₂₁₁ + 4⋅I₁⋅I₂⋅T₂₁₁₁₁ + I₁⋅I₂⋅T₂
#
# F(\Phi, E₁, E₂, I₁, I₂)
#
#                                                       2            2
# ₁₂₁₁ + E₁⋅E₂⋅P₁₁₂₂₂ + E₁⋅E₂⋅P₁₂₁₁₁ + E₁⋅E₂⋅P₁₂₁₂₂ + E₂ ⋅P₁₁₁₁₁ + E₂ ⋅P₁₂₂₁₁ +
#
#                                                       2            2
# ₁₂₁₁ + E₁⋅E₂⋅P₂₁₂₂₂ + E₁⋅E₂⋅P₂₂₁₁₁ + E₁⋅E₂⋅P₂₂₁₂₂ + E₂ ⋅P₂₁₁₁₁ + E₂ ⋅P₂₂₂₁₁ +
#
#                                                       2            2
# ₁₁₁₂ + I₁⋅I₂⋅T₁₁₁₂₁ + I₁⋅I₂⋅T₁₂₂₁₂ + I₁⋅I₂⋅T₁₂₂₂₁ + I₂ ⋅T₁₁₁₁₁ + I₂ ⋅T₁₁₁₂₂ +
#
#                                                       2            2
# ₁₁₁₂ + I₁⋅I₂⋅T₂₁₁₂₁ + I₁⋅I₂⋅T₂₂₂₁₂ + I₁⋅I₂⋅T₂₂₂₂₁ + I₂ ⋅T₂₁₁₁₁ + I₂ ⋅T₂₁₁₂₂ +
#
#                        ⎤
#                        ⎥
#   2            2       ⎥
# E₂ ⋅P₁₂₂₁₂ + E₂ ⋅P₁₂₂₂₁⎥
#                        ⎥
#   2            2       ⎥
# E₂ ⋅P₂₂₂₁₂ + E₂ ⋅P₂₂₂₂₁⎥
#                        ⎥
#   2            2       ⎥
# I₂ ⋅T₁₁₂₂₂ + I₂ ⋅T₁₂₁₂₂⎥
#                        ⎥
#   2            2       ⎥
# I₂ ⋅T₂₁₂₂₂ + I₂ ⋅T₂₂₁₂₂⎦

# %%
simbolo = S_component002(1,1,L0,ZE)
check = poly_args(simbolo,dc,dZE,factor)

# %%
ambar = []
for x in check:
    ambar.append(factor(check[x]))

# %%
Matrix(list(check.keys())),Matrix(ambar)
# Out:
# ⎛⎡            -n   n   r + s   -r - s + 2          ⎤
# ⎜⎢          E₁  ⋅E₂ ⋅I₁     ⋅I₂                    ⎥, ⎡
# ⎜⎢                                                 ⎥  ⎢
# ⎜⎢                -m   m   -r + 2   r              ⎥  ⎢
# ⎜⎢              E₁  ⋅E₂ ⋅I₁      ⋅I₂               ⎥  ⎢
# ⎜⎢                                                 ⎥  ⎢
# ⎜⎢    m - n - 1   -m + n + 1   -r - s + 2   r + s  ⎥  ⎢
# ⎜⎢  E₁         ⋅E₂          ⋅I₁          ⋅I₂       ⎥  ⎢
# ⎜⎢                                                 ⎥  ⎢
# ⎜⎢                r - s + 1   -r + s + 1           ⎥  ⎢
# ⎜⎢           E₂⋅I₁         ⋅I₂                     ⎥  ⎢
# ⎜⎢           ───────────────────────────           ⎥  ⎢
# ⎜⎢                        E₁                       ⎥  ⎢
# ⎜⎢                                                 ⎥  ⎢
# ⎜⎢          m - 1   -m + 1   -s + 1   s + 1        ⎥  ⎢
# ⎜⎢        E₁     ⋅E₂      ⋅I₁      ⋅I₂             ⎥  ⎢
# ⎜⎢                                                 ⎥  ⎢
# ⎜⎢                    s   -s + 2                   ⎥  ⎢
# ⎜⎢                  I₁ ⋅I₂                         ⎥  ⎢
# ⎜⎢                                                 ⎥  ⎢
# ⎜⎢            n - 1   -n + 1   -s + 2   s          ⎥  ⎢
# ⎜⎢          E₁     ⋅E₂      ⋅I₁      ⋅I₂           ⎥  ⎢
# ⎜⎢                                                 ⎥  ⎢
# ⎜⎢        -m + n - 1   m - n + 1   -s + 2   s      ⎥  ⎢
# ⎜⎢      E₁          ⋅E₂         ⋅I₁      ⋅I₂       ⎥  ⎢
# ⎜⎢                                                 ⎥  ⎢
# ⎜⎢      -m + n - 1   m - n + 1   -s + 1   s + 1    ⎥  ⎢
# ⎜⎢    E₁          ⋅E₂         ⋅I₁      ⋅I₂         ⎥  ⎢
# ⎜⎢                                                 ⎥  ⎢
# ⎜⎢                  -s + 1   s + 1                 ⎥  ⎢
# ⎜⎢                I₁      ⋅I₂                      ⎥  ⎢
# ⎜⎢                                                 ⎥  ⎢
# ⎜⎢          n - 1   -n + 1   -s + 1   s + 1        ⎥  ⎢
# ⎜⎢        E₁     ⋅E₂      ⋅I₁      ⋅I₂             ⎥  ⎢
# ⎜⎢                                                 ⎥  ⎢
# ⎜⎢      -m + n - 1   m - n + 1   -r + 1   r + 1    ⎥  ⎢
# ⎜⎢    E₁          ⋅E₂         ⋅I₁      ⋅I₂         ⎥  ⎢
# ⎜⎢                                                 ⎥  ⎢
# ⎜⎢          -m   m   -r + s + 1   r - s + 1        ⎥  ⎢
# ⎜⎢        E₁  ⋅E₂ ⋅I₁          ⋅I₂                 ⎥  ⎢
# ⎜⎢                                                 ⎥  ⎢
# ⎜⎢                      I₁⋅I₂                      ⎥  ⎢
# ⎜⎢                                                 ⎥  ⎢
# ⎜⎢      -m + n - 1   m - n + 1   s + 1   -s + 1    ⎥  ⎢
# ⎜⎢    E₁          ⋅E₂         ⋅I₁     ⋅I₂          ⎥  ⎢
# ⎜⎢                                                 ⎥  ⎢
# ⎜⎢                -n   n   -s + 2   s              ⎥  ⎢
# ⎜⎢              E₁  ⋅E₂ ⋅I₁      ⋅I₂               ⎥  ⎢
# ⎜⎢                                                 ⎥  ⎢
# ⎜⎢              -m   m   s + 1   -s + 1            ⎥  ⎢
# ⎜⎢            E₁  ⋅E₂ ⋅I₁     ⋅I₂                  ⎥  ⎢
# ⎜⎢                                                 ⎥  ⎢
# ⎜⎢          m - 1   -m + 1   s + 1   -s + 1        ⎥  ⎢
# ⎜⎢        E₁     ⋅E₂      ⋅I₁     ⋅I₂              ⎥  ⎢
# ⎜⎢                                                 ⎥  ⎢
# ⎜⎢            -m   m   -r - s + 2   r + s          ⎥  ⎢
# ⎜⎢          E₁  ⋅E₂ ⋅I₁          ⋅I₂               ⎥  ⎢
# ⎜⎢                                                 ⎥  ⎢
# ⎜⎢          -m   m   r - s + 1   -r + s + 1        ⎥  ⎢                 2
# ⎜⎢        E₁  ⋅E₂ ⋅I₁         ⋅I₂                  ⎥  ⎢- P₁₁₂₂₂⋅T₁₁₂₂₂⋅m  + P₁
# ⎜⎢                                                 ⎥  ⎢
# ⎜⎢                  r + 1   -r + 1                 ⎥  ⎢
# ⎜⎢                I₁     ⋅I₂                       ⎥  ⎢
# ⎜⎢                                                 ⎥  ⎢
# ⎜⎢            -n   n   -r - s + 2   r + s          ⎥  ⎢
# ⎜⎢          E₁  ⋅E₂ ⋅I₁          ⋅I₂               ⎥  ⎢
# ⎜⎢                                                 ⎥  ⎢
# ⎜⎢        m - n - 1   -m + n + 1   s   -s + 2      ⎥  ⎢
# ⎜⎢      E₁         ⋅E₂          ⋅I₁ ⋅I₂            ⎥  ⎢
# ⎜⎢                                                 ⎥  ⎢
# ⎜⎢    -m + n - 1   m - n + 1   r + s   -r - s + 2  ⎥  ⎢
# ⎜⎢  E₁          ⋅E₂         ⋅I₁     ⋅I₂            ⎥  ⎢
# ⎜⎢                                                 ⎥  ⎢
# ⎜⎢        n - 1   -n + 1   r + s   -r - s + 2      ⎥  ⎢
# ⎜⎢      E₁     ⋅E₂      ⋅I₁     ⋅I₂                ⎥  ⎢
# ⎜⎢                                                 ⎥  ⎢
# ⎜⎢  -m + n - 1   m - n + 1   -r + s + 1   r - s + 1⎥  ⎢
# ⎜⎢E₁          ⋅E₂         ⋅I₁          ⋅I₂         ⎥  ⎢
# ⎜⎢                                                 ⎥  ⎢
# ⎜⎢    -m + n - 1   m - n + 1   -r - s + 2   r + s  ⎥  ⎢
# ⎜⎢  E₁          ⋅E₂         ⋅I₁          ⋅I₂       ⎥  ⎢
# ⎜⎢                                                 ⎥  ⎢
# ⎜⎢                -r - s + 2   r + s               ⎥  ⎢
# ⎜⎢              I₁          ⋅I₂                    ⎥  ⎢
# ⎜⎢                                                 ⎥  ⎢
# ⎜⎢                          2                      ⎥  ⎢
# ⎜⎢                     E₂⋅I₂                       ⎥  ⎢
# ⎜⎢                     ──────                      ⎥  ⎢
# ⎜⎢                       E₁                        ⎥  ⎢
# ⎜⎢                                                 ⎥  ⎢
# ⎜⎢        n - 1   -n + 1   -r - s + 2   r + s      ⎥  ⎢
# ⎜⎢      E₁     ⋅E₂      ⋅I₁          ⋅I₂           ⎥  ⎢
# ⎜⎢                                                 ⎥  ⎢
# ⎜⎢                    -m   m   2                   ⎥  ⎢
# ⎜⎢                  E₁  ⋅E₂ ⋅I₂                    ⎥  ⎢
# ⎜⎢                                                 ⎥  ⎢
# ⎜⎢                n - 1   -n + 1   2               ⎥  ⎢
# ⎜⎢              E₁     ⋅E₂      ⋅I₂                ⎥  ⎢
# ⎜⎢                                                 ⎥  ⎢
# ⎜⎢                    -n   n   2                   ⎥  ⎢
# ⎜⎢                  E₁  ⋅E₂ ⋅I₂                    ⎥  ⎢
# ⎜⎢                                                 ⎥  ⎢
# ⎜⎢          m - 1   -m + 1   r + 1   -r + 1        ⎥  ⎢
# ⎜⎢        E₁     ⋅E₂      ⋅I₁     ⋅I₂              ⎥  ⎢
# ⎜⎢                                                 ⎥  ⎢
# ⎜⎢                -n   n   -r + 2   r              ⎥  ⎢
# ⎜⎢              E₁  ⋅E₂ ⋅I₁      ⋅I₂               ⎥  ⎢
# ⎜⎢                                                 ⎥  ⎢
# ⎜⎢        m - n - 1   -m + n + 1   r   -r + 2      ⎥  ⎢
# ⎜⎢      E₁         ⋅E₂          ⋅I₁ ⋅I₂            ⎥  ⎢
# ⎜⎢                                                 ⎥  ⎢
# ⎜⎢               n - 1   -n + 1                    ⎥  ⎢
# ⎜⎢             E₁     ⋅E₂      ⋅I₁⋅I₂              ⎥  ⎢
# ⎜⎢                                                 ⎥  ⎢
# ⎜⎢            n - 1   -n + 1   r   -r + 2          ⎥  ⎢                 2
# ⎜⎢          E₁     ⋅E₂      ⋅I₁ ⋅I₂                ⎥  ⎢- P₁₁₁₁₁⋅T₁₁₂₁₁⋅m  + P₁
# ⎜⎢                                                 ⎥  ⎢
# ⎜⎢           -m + n - 1   m - n + 1                ⎥  ⎢
# ⎜⎢         E₁          ⋅E₂         ⋅I₁⋅I₂          ⎥  ⎢
# ⎜⎢                                                 ⎥  ⎢
# ⎜⎢                         2                       ⎥  ⎢
# ⎜⎢                       I₂                        ⎥  ⎢
# ⎜⎢                                                 ⎥  ⎢
# ⎜⎢        -m + n - 1   m - n + 1   -r + 2   r      ⎥  ⎢                 2
# ⎜⎢      E₁          ⋅E₂         ⋅I₁      ⋅I₂       ⎥  ⎢- P₁₁₂₁₁⋅T₁₁₂₁₁⋅m  + P₁
# ⎜⎢                                                 ⎥  ⎢
# ⎜⎢        m - n - 1   -m + n + 1   -s + 2   s      ⎥  ⎢
# ⎜⎢      E₁         ⋅E₂          ⋅I₁      ⋅I₂       ⎥  ⎢
# ⎜⎢                                                 ⎥  ⎢
# ⎜⎢                -m   m   r   -r + 2              ⎥  ⎢
# ⎜⎢              E₁  ⋅E₂ ⋅I₁ ⋅I₂                    ⎥  ⎢
# ⎜⎢                                                 ⎥  ⎢
# ⎜⎢        m - 1   -m + 1   r + s   -r - s + 2      ⎥  ⎢                 2
# ⎜⎢      E₁     ⋅E₂      ⋅I₁     ⋅I₂                ⎥  ⎢- P₁₁₂₂₂⋅T₁₁₁₁₁⋅m  + P₁
# ⎜⎢                                                 ⎥  ⎢
# ⎜⎢            m - n - 1   -m + n + 1   2           ⎥  ⎢
# ⎜⎢          E₁         ⋅E₂          ⋅I₁            ⎥  ⎢
# ⎜⎢                                                 ⎥  ⎢
# ⎜⎢                    E₂⋅I₁⋅I₂                     ⎥  ⎢
# ⎜⎢                    ────────                     ⎥  ⎢
# ⎜⎢                       E₁                        ⎥  ⎢
# ⎜⎢                                                 ⎥  ⎢
# ⎜⎢            -m + n - 1   m - n + 1   2           ⎥  ⎢
# ⎜⎢          E₁          ⋅E₂         ⋅I₂            ⎥  ⎢
# ⎜⎢                                                 ⎥  ⎢
# ⎜⎢      m - 1   -m + 1   r - s + 1   -r + s + 1    ⎥  ⎢
# ⎜⎢    E₁     ⋅E₂      ⋅I₁         ⋅I₂              ⎥  ⎢
# ⎜⎢                                                 ⎥  ⎢
# ⎜⎢        m - n - 1   -m + n + 1   -r + 2   r      ⎥  ⎢
# ⎜⎢      E₁         ⋅E₂          ⋅I₁      ⋅I₂       ⎥  ⎢
# ⎜⎢                                                 ⎥  ⎢
# ⎜⎢            m - 1   -m + 1   r   -r + 2          ⎥  ⎢
# ⎜⎢          E₁     ⋅E₂      ⋅I₁ ⋅I₂                ⎥  ⎢
# ⎜⎢                                                 ⎥  ⎢
# ⎜⎢              -m   m   -r + 1   r + 1            ⎥  ⎢
# ⎜⎢            E₁  ⋅E₂ ⋅I₁      ⋅I₂                 ⎥  ⎢
# ⎜⎢                                                 ⎥  ⎢
# ⎜⎢                m - 1   -m + 1   2               ⎥  ⎢
# ⎜⎢              E₁     ⋅E₂      ⋅I₁                ⎥  ⎢
# ⎜⎢                                                 ⎥  ⎢
# ⎜⎢                    -r + 2   r                   ⎥  ⎢
# ⎜⎢                  I₁      ⋅I₂                    ⎥  ⎢
# ⎜⎢                                                 ⎥  ⎢
# ⎜⎢      m - n - 1   -m + n + 1   r + 1   -r + 1    ⎥  ⎢                 2
# ⎜⎢    E₁         ⋅E₂          ⋅I₁     ⋅I₂          ⎥  ⎢- P₁₁₁₁₁⋅T₁₁₂₂₂⋅m  + P₁
# ⎜⎢                                                 ⎥  ⎢
# ⎜⎢            m - 1   -m + 1   s   -s + 2          ⎥  ⎢
# ⎜⎢          E₁     ⋅E₂      ⋅I₁ ⋅I₂                ⎥  ⎢
# ⎜⎢                                                 ⎥  ⎢                 2
# ⎜⎢                    r + 1   -r + 1               ⎥  ⎢- P₁₁₂₂₂⋅T₁₁₁₁₁⋅m  + P₁
# ⎜⎢               E₂⋅I₁     ⋅I₂                     ⎥  ⎢
# ⎜⎢               ───────────────────               ⎥  ⎢
# ⎜⎢                        E₁                       ⎥  ⎢
# ⎜⎢                                                 ⎥  ⎢
# ⎜⎢        m - 1   -m + 1   -r - s + 2   r + s      ⎥  ⎢
# ⎜⎢      E₁     ⋅E₂      ⋅I₁          ⋅I₂           ⎥  ⎢
# ⎜⎢                                                 ⎥  ⎢
# ⎜⎢  m - n - 1   -m + n + 1   r - s + 1   -r + s + 1⎥  ⎢
# ⎜⎢E₁         ⋅E₂          ⋅I₁         ⋅I₂          ⎥  ⎢
# ⎜⎢                                                 ⎥  ⎢
# ⎜⎢                -n   n   s   -s + 2              ⎥  ⎢
# ⎜⎢              E₁  ⋅E₂ ⋅I₁ ⋅I₂                    ⎥  ⎢
# ⎜⎢                                                 ⎥  ⎢
# ⎜⎢                          2                      ⎥  ⎢
# ⎜⎢                     E₂⋅I₁                       ⎥  ⎢
# ⎜⎢                     ──────                      ⎥  ⎢                 2
# ⎜⎢                       E₁                        ⎥  ⎢- P₁₁₁₁₁⋅T₁₁₂₁₁⋅m  + P₁
# ⎜⎢                                                 ⎥  ⎢
# ⎜⎢          n - 1   -n + 1   -r + 1   r + 1        ⎥  ⎢                 2
# ⎜⎢        E₁     ⋅E₂      ⋅I₁      ⋅I₂             ⎥  ⎢- P₁₁₂₁₁⋅T₁₁₁₁₁⋅m  + P₁
# ⎜⎢                                                 ⎥  ⎢
# ⎜⎢                   -m   m                        ⎥  ⎢
# ⎜⎢                 E₁  ⋅E₂ ⋅I₁⋅I₂                  ⎥  ⎢
# ⎜⎢                                                 ⎥  ⎢
# ⎜⎢            m - 1   -m + 1   -s + 2   s          ⎥  ⎢
# ⎜⎢          E₁     ⋅E₂      ⋅I₁      ⋅I₂           ⎥  ⎢
# ⎜⎢                                                 ⎥  ⎢
# ⎜⎢                      r   -r + 2                 ⎥  ⎢
# ⎜⎢                 E₂⋅I₁ ⋅I₂                       ⎥  ⎢
# ⎜⎢                 ───────────────                 ⎥  ⎢
# ⎜⎢                        E₁                       ⎥  ⎢
# ⎜⎢                                                 ⎥  ⎢
# ⎜⎢            m - n - 1   -m + n + 1   2           ⎥  ⎢
# ⎜⎢          E₁         ⋅E₂          ⋅I₂            ⎥  ⎢
# ⎜⎢                                                 ⎥  ⎢
# ⎜⎢            -m   m   r + s   -r - s + 2          ⎥  ⎢
# ⎜⎢          E₁  ⋅E₂ ⋅I₁     ⋅I₂                    ⎥  ⎢
# ⎜⎢                                                 ⎥  ⎢
# ⎜⎢                   -n   n                        ⎥  ⎢
# ⎜⎢                 E₁  ⋅E₂ ⋅I₁⋅I₂                  ⎥  ⎢                 2
# ⎜⎢                                                 ⎥  ⎢- P₁₁₁₁₁⋅T₁₁₂₂₂⋅m  + P₁
# ⎜⎢                -m   m   s   -s + 2              ⎥  ⎢
# ⎜⎢              E₁  ⋅E₂ ⋅I₁ ⋅I₂                    ⎥  ⎢
# ⎜⎢                                                 ⎥  ⎢
# ⎜⎢          m - 1   -m + 1   -r + 1   r + 1        ⎥  ⎢
# ⎜⎢        E₁     ⋅E₂      ⋅I₁      ⋅I₂             ⎥  ⎢
# ⎜⎢                                                 ⎥  ⎢
# ⎜⎢          -n   n   -r + s + 1   r - s + 1        ⎥  ⎢
# ⎜⎢        E₁  ⋅E₂ ⋅I₁          ⋅I₂                 ⎥  ⎢
# ⎜⎢                                                 ⎥  ⎢
# ⎜⎢                m - 1   -m + 1   2               ⎥  ⎢
# ⎜⎢              E₁     ⋅E₂      ⋅I₂                ⎥  ⎢
# ⎜⎢                                                 ⎥  ⎢
# ⎜⎢              -n   n   -s + 1   s + 1            ⎥  ⎢
# ⎜⎢            E₁  ⋅E₂ ⋅I₁      ⋅I₂                 ⎥  ⎢
# ⎜⎢                                                 ⎥  ⎢
# ⎜⎢                  s + 1   -s + 1                 ⎥  ⎢                 2
# ⎜⎢                I₁     ⋅I₂                       ⎥  ⎢- P₁₁₂₁₁⋅T₁₁₁₁₁⋅m  + P₁
# ⎜⎢                                                 ⎥  ⎢
# ⎜⎢          n - 1   -n + 1   s + 1   -s + 1        ⎥  ⎢
# ⎜⎢        E₁     ⋅E₂      ⋅I₁     ⋅I₂              ⎥  ⎢
# ⎜⎢                                                 ⎥  ⎢
# ⎜⎢                -m   m   -s + 2   s              ⎥  ⎢
# ⎜⎢              E₁  ⋅E₂ ⋅I₁      ⋅I₂               ⎥  ⎢
# ⎜⎢                                                 ⎥  ⎢
# ⎜⎢    m - n - 1   -m + n + 1   r + s   -r - s + 2  ⎥  ⎢
# ⎜⎢  E₁         ⋅E₂          ⋅I₁     ⋅I₂            ⎥  ⎢
# ⎜⎢                                                 ⎥  ⎢                 2
# ⎜⎢              -r + s + 1   r - s + 1             ⎥  ⎢- P₁₁₂₂₂⋅T₁₁₂₁₁⋅m  + P₁
# ⎜⎢            I₁          ⋅I₂                      ⎥  ⎢
# ⎜⎢                                                 ⎥  ⎢
# ⎜⎢  m - n - 1   -m + n + 1   -r + s + 1   r - s + 1⎥  ⎢
# ⎜⎢E₁         ⋅E₂          ⋅I₁          ⋅I₂         ⎥  ⎢
# ⎜⎢                                                 ⎥  ⎢
# ⎜⎢                    -s + 1   s + 1               ⎥  ⎢
# ⎜⎢               E₂⋅I₁      ⋅I₂                    ⎥  ⎢
# ⎜⎢               ───────────────────               ⎥  ⎢
# ⎜⎢                        E₁                       ⎥  ⎢
# ⎜⎢                                                 ⎥  ⎢
# ⎜⎢           m - n - 1   -m + n + 1                ⎥  ⎢
# ⎜⎢         E₁         ⋅E₂          ⋅I₁⋅I₂          ⎥  ⎢
# ⎜⎢                                                 ⎥  ⎢                 2
# ⎜⎢                      s   -s + 2                 ⎥  ⎢- P₁₁₂₁₁⋅T₁₁₂₂₂⋅m  + P₁
# ⎜⎢                 E₂⋅I₁ ⋅I₂                       ⎥  ⎢
# ⎜⎢                 ───────────────                 ⎥  ⎣
# ⎜⎢                        E₁                       ⎥
# ⎜⎢                                                 ⎥
# ⎜⎢                    -n   n   2                   ⎥
# ⎜⎢                  E₁  ⋅E₂ ⋅I₁                    ⎥
# ⎜⎢                                                 ⎥
# ⎜⎢                    -m   m   2                   ⎥
# ⎜⎢                  E₁  ⋅E₂ ⋅I₁                    ⎥
# ⎜⎢                                                 ⎥
# ⎜⎢                         2                       ⎥
# ⎜⎢                       I₁                        ⎥
# ⎜⎢                                                 ⎥
# ⎜⎢        -m + n - 1   m - n + 1   s   -s + 2      ⎥
# ⎜⎢      E₁          ⋅E₂         ⋅I₁ ⋅I₂            ⎥
# ⎜⎢                                                 ⎥
# ⎜⎢                -n   n   r   -r + 2              ⎥
# ⎜⎢              E₁  ⋅E₂ ⋅I₁ ⋅I₂                    ⎥
# ⎜⎢                                                 ⎥
# ⎜⎢              -n   n   s + 1   -s + 1            ⎥
# ⎜⎢            E₁  ⋅E₂ ⋅I₁     ⋅I₂                  ⎥
# ⎜⎢                                                 ⎥
# ⎜⎢            -m + n - 1   m - n + 1   2           ⎥
# ⎜⎢          E₁          ⋅E₂         ⋅I₁            ⎥
# ⎜⎢                                                 ⎥
# ⎜⎢                    s + 1   -s + 1               ⎥
# ⎜⎢               E₂⋅I₁     ⋅I₂                     ⎥
# ⎜⎢               ───────────────────               ⎥
# ⎜⎢                        E₁                       ⎥
# ⎜⎢                                                 ⎥
# ⎜⎢                      -r + 2   r                 ⎥
# ⎜⎢                 E₂⋅I₁      ⋅I₂                  ⎥
# ⎜⎢                 ───────────────                 ⎥
# ⎜⎢                        E₁                       ⎥
# ⎜⎢                                                 ⎥
# ⎜⎢               m - 1   -m + 1                    ⎥
# ⎜⎢             E₁     ⋅E₂      ⋅I₁⋅I₂              ⎥
# ⎜⎢                                                 ⎥
# ⎜⎢  -m + n - 1   m - n + 1   r - s + 1   -r + s + 1⎥
# ⎜⎢E₁          ⋅E₂         ⋅I₁         ⋅I₂          ⎥
# ⎜⎢                                                 ⎥
# ⎜⎢      n - 1   -n + 1   -r + s + 1   r - s + 1    ⎥
# ⎜⎢    E₁     ⋅E₂      ⋅I₁          ⋅I₂             ⎥
# ⎜⎢                                                 ⎥
# ⎜⎢          n - 1   -n + 1   r + 1   -r + 1        ⎥
# ⎜⎢        E₁     ⋅E₂      ⋅I₁     ⋅I₂              ⎥
# ⎜⎢                                                 ⎥
# ⎜⎢        -m + n - 1   m - n + 1   r   -r + 2      ⎥
# ⎜⎢      E₁          ⋅E₂         ⋅I₁ ⋅I₂            ⎥
# ⎜⎢                                                 ⎥
# ⎜⎢              -m   m   r + 1   -r + 1            ⎥
# ⎜⎢            E₁  ⋅E₂ ⋅I₁     ⋅I₂                  ⎥
# ⎜⎢                                                 ⎥
# ⎜⎢              -m   m   -s + 1   s + 1            ⎥
# ⎜⎢            E₁  ⋅E₂ ⋅I₁      ⋅I₂                 ⎥
# ⎜⎢                                                 ⎥
# ⎜⎢      -m + n - 1   m - n + 1   r + 1   -r + 1    ⎥
# ⎜⎢    E₁          ⋅E₂         ⋅I₁     ⋅I₂          ⎥
# ⎜⎢                                                 ⎥
# ⎜⎢            n - 1   -n + 1   -r + 2   r          ⎥
# ⎜⎢          E₁     ⋅E₂      ⋅I₁      ⋅I₂           ⎥
# ⎜⎢                                                 ⎥
# ⎜⎢                    -r + 1   r + 1               ⎥
# ⎜⎢               E₂⋅I₁      ⋅I₂                    ⎥
# ⎜⎢               ───────────────────               ⎥
# ⎜⎢                        E₁                       ⎥
# ⎜⎢                                                 ⎥
# ⎜⎢          -n   n   r - s + 1   -r + s + 1        ⎥
# ⎜⎢        E₁  ⋅E₂ ⋅I₁         ⋅I₂                  ⎥
# ⎜⎢                                                 ⎥
# ⎜⎢      m - 1   -m + 1   -r + s + 1   r - s + 1    ⎥
# ⎜⎢    E₁     ⋅E₂      ⋅I₁          ⋅I₂             ⎥
# ⎜⎢                                                 ⎥
# ⎜⎢            n - 1   -n + 1   s   -s + 2          ⎥
# ⎜⎢          E₁     ⋅E₂      ⋅I₁ ⋅I₂                ⎥
# ⎜⎢                                                 ⎥
# ⎜⎢                  -r + 1   r + 1                 ⎥
# ⎜⎢                I₁      ⋅I₂                      ⎥
# ⎜⎢                                                 ⎥
# ⎜⎢      m - n - 1   -m + n + 1   -s + 1   s + 1    ⎥
# ⎜⎢    E₁         ⋅E₂          ⋅I₁      ⋅I₂         ⎥
# ⎜⎢                                                 ⎥
# ⎜⎢      n - 1   -n + 1   r - s + 1   -r + s + 1    ⎥
# ⎜⎢    E₁     ⋅E₂      ⋅I₁         ⋅I₂              ⎥
# ⎜⎢                                                 ⎥
# ⎜⎢              -n   n   r + 1   -r + 1            ⎥
# ⎜⎢            E₁  ⋅E₂ ⋅I₁     ⋅I₂                  ⎥
# ⎜⎢                                                 ⎥
# ⎜⎢                      -s + 2   s                 ⎥
# ⎜⎢                 E₂⋅I₁      ⋅I₂                  ⎥
# ⎜⎢                 ───────────────                 ⎥
# ⎜⎢                        E₁                       ⎥
# ⎜⎢                                                 ⎥
# ⎜⎢              -n   n   -r + 1   r + 1            ⎥
# ⎜⎢            E₁  ⋅E₂ ⋅I₁      ⋅I₂                 ⎥
# ⎜⎢                                                 ⎥
# ⎜⎢              r - s + 1   -r + s + 1             ⎥
# ⎜⎢            I₁         ⋅I₂                       ⎥
# ⎜⎢                                                 ⎥
# ⎜⎢                    r   -r + 2                   ⎥
# ⎜⎢                  I₁ ⋅I₂                         ⎥
# ⎜⎢                                                 ⎥
# ⎜⎢      m - n - 1   -m + n + 1   s + 1   -s + 1    ⎥
# ⎜⎢    E₁         ⋅E₂          ⋅I₁     ⋅I₂          ⎥
# ⎜⎢                                                 ⎥
# ⎜⎢                  r + s   -r - s + 2             ⎥
# ⎜⎢             E₂⋅I₁     ⋅I₂                       ⎥
# ⎜⎢             ───────────────────────             ⎥
# ⎜⎢                        E₁                       ⎥
# ⎜⎢                                                 ⎥
# ⎜⎢                -r + s + 1   r - s + 1           ⎥
# ⎜⎢           E₂⋅I₁          ⋅I₂                    ⎥
# ⎜⎢           ───────────────────────────           ⎥
# ⎜⎢                        E₁                       ⎥
# ⎜⎢                                                 ⎥
# ⎜⎢            m - 1   -m + 1   -r + 2   r          ⎥
# ⎜⎢          E₁     ⋅E₂      ⋅I₁      ⋅I₂           ⎥
# ⎜⎢                                                 ⎥
# ⎜⎢                    -s + 2   s                   ⎥
# ⎜⎢                  I₁      ⋅I₂                    ⎥
# ⎜⎢                                                 ⎥
# ⎜⎢                n - 1   -n + 1   2               ⎥
# ⎜⎢              E₁     ⋅E₂      ⋅I₁                ⎥
# ⎜⎢                                                 ⎥
# ⎜⎢                r + s   -r - s + 2               ⎥
# ⎜⎢              I₁     ⋅I₂                         ⎥
# ⎜⎢                                                 ⎥
# ⎜⎢                  -r - s + 2   r + s             ⎥
# ⎜⎢             E₂⋅I₁          ⋅I₂                  ⎥
# ⎜⎢             ───────────────────────             ⎥
# ⎜⎢                        E₁                       ⎥
# ⎜⎢                                                 ⎥
# ⎜⎢      m - n - 1   -m + n + 1   -r + 1   r + 1    ⎥
# ⎝⎣    E₁         ⋅E₂          ⋅I₁      ⋅I₂         ⎦
#
#
#                            -m⋅(P₁₁₂₂₂⋅T₁₁₁₁₁ + P₂₁₂₂₂⋅T₂₁₁₁₁)⋅(m + n - 2)
#
#                            -n⋅(P₁₂₁₁₁⋅T₁₁₁₂₁ + P₂₂₁₁₁⋅T₂₁₁₂₁)⋅(m + n - 2)
#
#                              -m⋅(n - 1)⋅(P₁₁₂₁₁⋅T₁₂₁₂₂ + P₂₁₂₁₁⋅T₂₂₁₂₂)
#
#                                                           ⎛ 2        2    ⎞
#                          -(P₁₁₁₁₁⋅T₁₁₁₁₁ + P₂₁₁₁₁⋅T₂₁₁₁₁)⋅⎝m  - m + n  - n⎠
#
#                           -(m + n)⋅(n - 1)⋅(P₁₁₁₂₁⋅T₁₂₁₂₂ + P₂₁₁₂₁⋅T₂₂₁₂₂)
#
#                         -(m + n)⋅(P₁₁₁₂₂⋅T₁₁₁₂₁ + P₂₁₁₂₂⋅T₂₁₁₂₁)⋅(m + n - 2)
#
#                           -(m - 1)⋅(m + n)⋅(P₁₁₁₁₁⋅T₁₁₁₁₁ + P₂₁₁₁₁⋅T₂₁₁₁₁)
#
#                              -n⋅(m - 1)⋅(P₁₂₁₁₁⋅T₁₁₁₁₁ + P₂₂₁₁₁⋅T₂₁₁₁₁)
#
#                              -n⋅(m - 1)⋅(P₁₁₁₁₁⋅T₁₁₂₂₂ + P₂₁₁₁₁⋅T₂₁₂₂₂)
#
#                         -(m + n)⋅(P₁₁₁₂₁⋅T₁₁₁₂₂ + P₂₁₁₂₁⋅T₂₁₁₂₂)⋅(m + n - 2)
#
#                           -(m - 1)⋅(m + n)⋅(P₁₁₁₂₁⋅T₁₁₂₂₂ + P₂₁₁₂₁⋅T₂₁₂₂₂)
#
#                              -n⋅(m - 1)⋅(P₁₁₁₁₁⋅T₁₁₂₂₂ + P₂₁₁₁₁⋅T₂₁₂₂₂)
#
#                            -n⋅(P₁₁₁₁₁⋅T₁₁₁₂₁ + P₂₁₁₁₁⋅T₂₁₁₂₁)⋅(m + n - 2)
#
#         -(m + n)⋅(m + n - 2)⋅(P₁₁₁₁₂⋅T₁₁₁₁₂ + P₁₁₁₂₁⋅T₁₁₁₂₁ + P₂₁₁₁₂⋅T₂₁₁₁₂ +
#
#                              -n⋅(m - 1)⋅(P₁₁₁₁₁⋅T₁₁₂₁₁ + P₂₁₁₁₁⋅T₂₁₂₁₁)
#
#                            -m⋅(P₁₁₂₁₁⋅T₁₁₁₁₂ + P₂₁₂₁₁⋅T₂₁₁₁₂)⋅(m + n - 2)
#
#                            -n⋅(P₁₁₁₁₁⋅T₁₁₁₁₁ + P₂₁₁₁₁⋅T₂₁₁₁₁)⋅(m + n - 2)
#
#                           -(m + n)⋅(n - 1)⋅(P₁₁₁₁₂⋅T₁₂₁₁₁ + P₂₁₁₁₂⋅T₂₂₁₁₁)
#
#                            -n⋅(P₁₂₁₁₁⋅T₁₁₁₂₂ + P₂₂₁₁₁⋅T₂₁₁₂₂)⋅(m + n - 2)
#
#                            -n⋅(P₁₁₁₁₁⋅T₁₁₁₁₂ + P₂₁₁₁₁⋅T₂₁₁₁₂)⋅(m + n - 2)
#
#                         -(m + n)⋅(P₁₁₁₂₁⋅T₁₁₁₁₁ + P₂₁₁₂₁⋅T₂₁₁₁₁)⋅(m + n - 2)
#
#                            -m⋅(P₁₁₂₁₁⋅T₁₁₁₂₂ + P₂₁₂₁₁⋅T₂₁₁₂₂)⋅(m + n - 2)
#
#                              -m⋅(n - 1)⋅(P₁₁₂₂₂⋅T₁₁₁₁₁ + P₂₁₂₂₂⋅T₂₁₁₁₁)
#
#                              -n⋅(m - 1)⋅(P₁₂₁₂₂⋅T₁₁₂₁₁ + P₂₂₁₂₂⋅T₂₁₂₁₁)
#
#                           -(m - 1)⋅(m + n)⋅(P₁₁₁₂₂⋅T₁₁₂₁₁ + P₂₁₁₂₂⋅T₂₁₂₁₁)
#
#                              -n⋅(m - 1)⋅(P₁₁₁₁₁⋅T₁₁₁₁₁ + P₂₁₁₁₁⋅T₂₁₁₁₁)
#
#                              -n⋅(m - 1)⋅(P₁₂₁₁₁⋅T₁₁₂₂₂ + P₂₂₁₁₁⋅T₂₁₂₂₂)
#
#                         -(m + n)⋅(P₁₁₁₁₁⋅T₁₁₁₂₂ + P₂₁₁₁₁⋅T₂₁₁₂₂)⋅(m + n - 2)
#
#                                2                                    2
# ₁₂₂₂⋅T₁₁₂₂₂⋅m - P₁₂₁₂₂⋅T₁₂₁₂₂⋅n  + P₁₂₁₂₂⋅T₁₂₁₂₂⋅n - P₂₁₂₂₂⋅T₂₁₂₂₂⋅m  + P₂₁₂₂₂
#
#                           -(m - 1)⋅(m + n)⋅(P₁₁₁₁₁⋅T₁₁₂₂₂ + P₂₁₁₁₁⋅T₂₁₂₂₂)
#
#                            -n⋅(P₁₂₁₂₂⋅T₁₁₁₂₂ + P₂₂₁₂₂⋅T₂₁₁₂₂)⋅(m + n - 2)
#
#                           -(m - 1)⋅(m + n)⋅(P₁₁₁₂₂⋅T₁₁₂₂₂ + P₂₁₁₂₂⋅T₂₁₂₂₂)
#
#                            -m⋅(P₁₁₂₂₂⋅T₁₁₁₂₂ + P₂₁₂₂₂⋅T₂₁₁₂₂)⋅(m + n - 2)
#
#                           -(m + n)⋅(n - 1)⋅(P₁₁₁₂₁⋅T₁₂₁₁₁ + P₂₁₁₂₁⋅T₂₂₁₁₁)
#
#                            -m⋅(P₁₁₂₁₁⋅T₁₁₁₂₁ + P₂₁₂₁₁⋅T₂₁₁₂₁)⋅(m + n - 2)
#
#                              -m⋅(n - 1)⋅(P₁₁₂₂₂⋅T₁₁₁₁₁ + P₂₁₂₂₂⋅T₂₁₁₁₁)
#
#           -(m - 1)⋅(m + n)⋅(P₁₁₁₁₂⋅T₁₁₁₁₁ + P₁₁₁₂₁⋅T₁₁₁₁₁ + P₂₁₁₁₂⋅T₂₁₁₁₁ + P₂
#
#                           -(m - 1)⋅(m + n)⋅(P₁₁₁₂₂⋅T₁₁₁₁₁ + P₂₁₁₂₂⋅T₂₁₁₁₁)
#
#                             -2⋅n⋅(m - 1)⋅(P₁₁₁₁₁⋅T₁₁₁₁₁ + P₂₁₁₁₁⋅T₂₁₁₁₁)
#
#                         -(m + n)⋅(P₁₁₁₂₂⋅T₁₁₁₂₂ + P₂₁₁₂₂⋅T₂₁₁₂₂)⋅(m + n - 2)
#
#                              -n⋅(m - 1)⋅(P₁₂₁₁₁⋅T₁₁₁₁₁ + P₂₂₁₁₁⋅T₂₁₁₁₁)
#
#                              -m⋅(n - 1)⋅(P₁₁₂₁₁⋅T₁₁₁₁₁ + P₂₁₂₁₁⋅T₂₁₁₁₁)
#
#                            -n⋅(P₁₂₁₂₂⋅T₁₁₁₁₂ + P₂₂₁₂₂⋅T₂₁₁₁₂)⋅(m + n - 2)
#
#                           -(m + n)⋅(n - 1)⋅(P₁₁₁₂₂⋅T₁₂₁₁₁ + P₂₁₁₂₂⋅T₂₂₁₁₁)
#
#                              -m⋅(n - 1)⋅(P₁₁₂₁₁⋅T₁₂₁₁₁ + P₂₁₂₁₁⋅T₂₂₁₁₁)
#
#                                                            ⎛ 2        2    ⎞
#                         -2⋅(P₁₁₁₁₁⋅T₁₁₁₁₁ + P₂₁₁₁₁⋅T₂₁₁₁₁)⋅⎝m  - m + n  - n⎠
#
#                              -n⋅(m - 1)⋅(P₁₂₁₂₂⋅T₁₁₂₂₂ + P₂₂₁₂₂⋅T₂₁₂₂₂)
#
#                           -(m + n)⋅(n - 1)⋅(P₁₁₁₂₁⋅T₁₁₁₁₁ + P₂₁₁₂₁⋅T₂₁₁₁₁)
#
#                              -m⋅(n - 1)⋅(P₁₁₂₁₁⋅T₁₁₁₁₁ + P₂₁₂₁₁⋅T₂₁₁₁₁)
#
#                           -(m + n)⋅(n - 1)⋅(P₁₁₁₂₂⋅T₁₁₁₁₁ + P₂₁₁₂₂⋅T₂₁₁₁₁)
#
#                            -n⋅(P₁₁₁₁₁⋅T₁₁₁₂₂ + P₂₁₁₁₁⋅T₂₁₁₂₂)⋅(m + n - 2)
#
#                           -(m + n)⋅(n - 1)⋅(P₁₁₁₁₁⋅T₁₂₁₁₁ + P₂₁₁₁₁⋅T₂₂₁₁₁)
#
#                         -(m + n)⋅(P₁₁₁₁₁⋅T₁₁₁₂₁ + P₂₁₁₁₁⋅T₂₁₁₂₁)⋅(m + n - 2)
#
#                              -m⋅(n - 1)⋅(P₁₁₁₁₁⋅T₁₂₁₁₁ + P₂₁₁₁₁⋅T₂₂₁₁₁)
#
#                           -(m + n)⋅(n - 1)⋅(P₁₁₁₂₂⋅T₁₁₁₁₁ + P₂₁₁₂₂⋅T₂₁₁₁₁)
#
#                                2                                    2
# ₁₁₁₁⋅T₁₁₂₁₁⋅m - P₁₁₁₁₁⋅T₁₂₁₁₁⋅n  + P₁₁₁₁₁⋅T₁₂₁₁₁⋅n - P₂₁₁₁₁⋅T₂₁₂₁₁⋅m  + P₂₁₁₁₁
#
#                           -(m + n)⋅(n - 1)⋅(P₁₁₁₁₁⋅T₁₂₁₂₂ + P₂₁₁₁₁⋅T₂₂₁₂₂)
#
#                              -m⋅(n - 1)⋅(P₁₁₁₁₁⋅T₁₁₁₁₁ + P₂₁₁₁₁⋅T₂₁₁₁₁)
#
#                            -m⋅(P₁₁₂₂₂⋅T₁₁₁₂₁ + P₂₁₂₂₂⋅T₂₁₁₂₁)⋅(m + n - 2)
#
#                                2                                    2
# ₁₂₁₁⋅T₁₁₂₁₁⋅m - P₁₂₁₁₁⋅T₁₂₁₁₁⋅n  + P₁₂₁₁₁⋅T₁₂₁₁₁⋅n - P₂₁₂₁₁⋅T₂₁₂₁₁⋅m  + P₂₁₂₁₁
#
#                           -(m - 1)⋅(m + n)⋅(P₁₁₁₁₂⋅T₁₁₂₂₂ + P₂₁₁₁₂⋅T₂₁₂₂₂)
#
#            -n⋅(m + n - 2)⋅(P₁₁₁₁₁⋅T₁₁₁₁₂ + P₁₁₁₁₁⋅T₁₁₁₂₁ + P₂₁₁₁₁⋅T₂₁₁₁₂ + P₂₁
#
#                           -(m + n)⋅(n - 1)⋅(P₁₁₁₁₁⋅T₁₁₁₁₁ + P₂₁₁₁₁⋅T₂₁₁₁₁)
#
#                                2                                    2
# ₁₂₂₂⋅T₁₁₁₁₁⋅m - P₁₂₁₂₂⋅T₁₁₁₁₁⋅n  + P₁₂₁₂₂⋅T₁₁₁₁₁⋅n - P₂₁₂₂₂⋅T₂₁₁₁₁⋅m  + P₂₁₂₂₂
#
#                              -m⋅(n - 1)⋅(P₁₁₂₂₂⋅T₁₂₁₂₂ + P₂₁₂₂₂⋅T₂₂₁₂₂)
#
#                            -n⋅(P₁₂₁₂₂⋅T₁₁₁₁₁ + P₂₂₁₂₂⋅T₂₁₁₁₁)⋅(m + n - 2)
#
#            -m⋅(m + n - 2)⋅(P₁₁₁₁₁⋅T₁₁₁₁₂ + P₁₁₁₁₁⋅T₁₁₁₂₁ + P₂₁₁₁₁⋅T₂₁₁₁₂ + P₂₁
#
#                            -n⋅(P₁₂₁₂₂⋅T₁₁₁₂₁ + P₂₂₁₂₂⋅T₂₁₁₂₁)⋅(m + n - 2)
#
#                           -(m + n)⋅(n - 1)⋅(P₁₁₁₁₂⋅T₁₂₁₂₂ + P₂₁₁₁₂⋅T₂₂₁₂₂)
#
#                            -m⋅(P₁₁₁₁₁⋅T₁₁₁₂₁ + P₂₁₁₁₁⋅T₂₁₁₂₁)⋅(m + n - 2)
#
#                           -(m + n)⋅(n - 1)⋅(P₁₁₁₂₂⋅T₁₂₁₂₂ + P₂₁₁₂₂⋅T₂₂₁₂₂)
#
#                            -m⋅(P₁₁₁₁₁⋅T₁₁₁₂₂ + P₂₁₁₁₁⋅T₂₁₁₂₂)⋅(m + n - 2)
#
#                         -(m + n)⋅(P₁₁₁₁₂⋅T₁₁₁₁₁ + P₂₁₁₁₂⋅T₂₁₁₁₁)⋅(m + n - 2)
#
#                           -(m - 1)⋅(m + n)⋅(P₁₁₁₁₂⋅T₁₁₂₁₁ + P₂₁₁₁₂⋅T₂₁₂₁₁)
#
#                            -n⋅(P₁₂₁₁₁⋅T₁₁₁₁₂ + P₂₂₁₁₁⋅T₂₁₁₁₂)⋅(m + n - 2)
#
#                              -m⋅(n - 1)⋅(P₁₁₂₂₂⋅T₁₂₁₁₁ + P₂₁₂₂₂⋅T₂₂₁₁₁)
#
#                         -(m + n)⋅(P₁₁₁₁₂⋅T₁₁₁₂₁ + P₂₁₁₁₂⋅T₂₁₁₂₁)⋅(m + n - 2)
#
#                              -m⋅(n - 1)⋅(P₁₁₁₁₁⋅T₁₁₁₁₁ + P₂₁₁₁₁⋅T₂₁₁₁₁)
#
#                                2                                    2
# ₁₁₁₁⋅T₁₁₂₂₂⋅m - P₁₁₁₁₁⋅T₁₂₁₂₂⋅n  + P₁₁₁₁₁⋅T₁₂₁₂₂⋅n - P₂₁₁₁₁⋅T₂₁₂₂₂⋅m  + P₂₁₁₁₁
#
#                             -2⋅m⋅(n - 1)⋅(P₁₁₁₁₁⋅T₁₁₁₁₁ + P₂₁₁₁₁⋅T₂₁₁₁₁)
#
#                                2                                    2
# ₁₂₂₂⋅T₁₁₁₁₁⋅m - P₁₂₁₂₂⋅T₁₁₁₁₁⋅n  + P₁₂₁₂₂⋅T₁₁₁₁₁⋅n - P₂₁₂₂₂⋅T₂₁₁₁₁⋅m  + P₂₁₂₂₂
#
#                            -m⋅(P₁₁₂₁₁⋅T₁₁₁₁₁ + P₂₁₂₁₁⋅T₂₁₁₁₁)⋅(m + n - 2)
#
#                            -n⋅(P₁₂₁₁₁⋅T₁₁₁₁₁ + P₂₂₁₁₁⋅T₂₁₁₁₁)⋅(m + n - 2)
#
#                         -(m + n)⋅(P₁₁₁₁₁⋅T₁₁₁₁₁ + P₂₁₁₁₁⋅T₂₁₁₁₁)⋅(m + n - 2)
#
#                              -n⋅(m - 1)⋅(P₁₂₁₂₂⋅T₁₁₁₁₁ + P₂₂₁₂₂⋅T₂₁₁₁₁)
#
#                            -m⋅(P₁₁₂₂₂⋅T₁₁₁₁₂ + P₂₁₂₂₂⋅T₂₁₁₁₂)⋅(m + n - 2)
#
#                            -m⋅(P₁₁₁₁₁⋅T₁₁₁₁₁ + P₂₁₁₁₁⋅T₂₁₁₁₁)⋅(m + n - 2)
#
#                              -n⋅(m - 1)⋅(P₁₂₁₁₁⋅T₁₁₂₁₁ + P₂₂₁₁₁⋅T₂₁₂₁₁)
#
#                                2                                    2
# ₁₁₁₁⋅T₁₁₂₁₁⋅m - P₁₁₁₁₁⋅T₁₂₁₁₁⋅n  + P₁₁₁₁₁⋅T₁₂₁₁₁⋅n - P₂₁₁₁₁⋅T₂₁₂₁₁⋅m  + P₂₁₁₁₁
#
#                                2                                    2
# ₁₂₁₁⋅T₁₁₁₁₁⋅m - P₁₂₁₁₁⋅T₁₁₁₁₁⋅n  + P₁₂₁₁₁⋅T₁₁₁₁₁⋅n - P₂₁₂₁₁⋅T₂₁₁₁₁⋅m  + P₂₁₂₁₁
#
#           -(m + n)⋅(n - 1)⋅(P₁₁₁₁₂⋅T₁₁₁₁₁ + P₁₁₁₂₁⋅T₁₁₁₁₁ + P₂₁₁₁₂⋅T₂₁₁₁₁ + P₂
#
#                              -n⋅(m - 1)⋅(P₁₁₁₁₁⋅T₁₁₁₁₁ + P₂₁₁₁₁⋅T₂₁₁₁₁)
#
#                           -(m - 1)⋅(m + n)⋅(P₁₁₁₁₂⋅T₁₁₁₁₁ + P₂₁₁₁₂⋅T₂₁₁₁₁)
#
#                           -(m - 1)⋅(m + n)⋅(P₁₁₁₂₁⋅T₁₁₂₁₁ + P₂₁₁₂₁⋅T₂₁₂₁₁)
#
#                              -n⋅(m - 1)⋅(P₁₂₁₂₂⋅T₁₁₁₁₁ + P₂₂₁₂₂⋅T₂₁₁₁₁)
#
#                            -n⋅(P₁₁₁₁₁⋅T₁₁₁₁₁ + P₂₁₁₁₁⋅T₂₁₁₁₁)⋅(m + n - 2)
#
#                            -n⋅(P₁₁₁₁₁⋅T₁₁₁₂₂ + P₂₁₁₁₁⋅T₂₁₁₂₂)⋅(m + n - 2)
#
#                              -n⋅(m - 1)⋅(P₁₁₁₁₁⋅T₁₁₂₁₁ + P₂₁₁₁₁⋅T₂₁₂₁₁)
#
#                           -(m - 1)⋅(m + n)⋅(P₁₁₁₁₁⋅T₁₁₁₁₁ + P₂₁₁₁₁⋅T₂₁₁₁₁)
#
#                                2                                    2
# ₁₁₁₁⋅T₁₁₂₂₂⋅m - P₁₁₁₁₁⋅T₁₂₁₂₂⋅n  + P₁₁₁₁₁⋅T₁₂₁₂₂⋅n - P₂₁₁₁₁⋅T₂₁₂₂₂⋅m  + P₂₁₁₁₁
#
#                            -m⋅(P₁₁₁₁₁⋅T₁₁₁₁₂ + P₂₁₁₁₁⋅T₂₁₁₁₂)⋅(m + n - 2)
#
#                           -(m + n)⋅(n - 1)⋅(P₁₁₁₁₂⋅T₁₁₁₁₁ + P₂₁₁₁₂⋅T₂₁₁₁₁)
#
#                           -(m - 1)⋅(m + n)⋅(P₁₁₁₂₂⋅T₁₁₁₁₁ + P₂₁₁₂₂⋅T₂₁₁₁₁)
#
#                         -(m + n)⋅(P₁₁₁₁₂⋅T₁₁₁₂₂ + P₂₁₁₁₂⋅T₂₁₁₂₂)⋅(m + n - 2)
#
# ...
#                                               ⎥⎟
#                                               ⎥⎟
#                                               ⎥⎟
#                                               ⎥⎟
#                                               ⎥⎟
#                                               ⎥⎟
#                                               ⎥⎟
#                                               ⎥⎟
#                                               ⎥⎟
#                                               ⎥⎟
#                                               ⎥⎟
#                                               ⎥⎟
#                                               ⎥⎟
#                                               ⎥⎟
# ₁₁₂₁⋅T₂₁₁₁₁)                                  ⎥⎟
#                                               ⎥⎟
#                                               ⎥⎟
#                                               ⎥⎟
#                                               ⎥⎟
#                                               ⎥⎟
#                                               ⎥⎟
#                                               ⎥⎟
#                                               ⎥⎟
#                                               ⎥⎟
#                                               ⎥⎟
#                                               ⎥⎟
#                                               ⎥⎟
#                                               ⎥⎟
#                                               ⎥⎟
#                                               ⎥⎟
#                                               ⎥⎟
#                                               ⎥⎟
#                                               ⎥⎟
#                                               ⎥⎟
#                                               ⎥⎟
#                                               ⎥⎟
#                                               ⎥⎟
#                                               ⎥⎟
#                                               ⎥⎟
#                                               ⎥⎟
#                                               ⎥⎟
#                                               ⎥⎟
#                                               ⎥⎟
#                                               ⎥⎟
#                                               ⎥⎟
#                                               ⎥⎟
#                                               ⎥⎟
#                                               ⎥⎟
#                                               ⎥⎟
#                                               ⎥⎟
#                                               ⎥⎟
#                                               ⎥⎟
#                                               ⎥⎟
#                            2                  ⎥⎟
# ⋅T₂₁₂₁₁⋅m - P₂₁₁₁₁⋅T₂₂₁₁₁⋅n  + P₂₁₁₁₁⋅T₂₂₁₁₁⋅n⎥⎟
#                                               ⎥⎟
#                                               ⎥⎟
#                                               ⎥⎟
#                                               ⎥⎟
#                                               ⎥⎟
#                                               ⎥⎟
#                                               ⎥⎟
#                            2                  ⎥⎟
# ⋅T₂₁₂₁₁⋅m - P₂₂₁₁₁⋅T₂₂₁₁₁⋅n  + P₂₂₁₁₁⋅T₂₂₁₁₁⋅n⎥⎟
#                                               ⎥⎟
#                                               ⎥⎟
#                                               ⎥⎟
# ₁₁₁⋅T₂₁₁₂₁)                                   ⎥⎟
#                                               ⎥⎟
#                                               ⎥⎟
#                                               ⎥⎟
#                            2                  ⎥⎟
# ⋅T₂₁₁₁₁⋅m - P₂₂₁₂₂⋅T₂₁₁₁₁⋅n  + P₂₂₁₂₂⋅T₂₁₁₁₁⋅n⎥⎟
#                                               ⎥⎟
#                                               ⎥⎟
#                                               ⎥⎟
#                                               ⎥⎟
#                                               ⎥⎟
# ₁₁₁⋅T₂₁₁₂₁)                                   ⎥⎟
#                                               ⎥⎟
#                                               ⎥⎟
#                                               ⎥⎟
#                                               ⎥⎟
#                                               ⎥⎟
#                                               ⎥⎟
#                                               ⎥⎟
#                                               ⎥⎟
#                                               ⎥⎟
#                                               ⎥⎟
#                                               ⎥⎟
#                                               ⎥⎟
#                                               ⎥⎟
#                                               ⎥⎟
#                                               ⎥⎟
#                                               ⎥⎟
#                                               ⎥⎟
#                                               ⎥⎟
#                                               ⎥⎟
#                                               ⎥⎟
#                                               ⎥⎟
#                                               ⎥⎟
#                                               ⎥⎟
#                            2                  ⎥⎟
# ⋅T₂₁₂₂₂⋅m - P₂₁₁₁₁⋅T₂₂₁₂₂⋅n  + P₂₁₁₁₁⋅T₂₂₁₂₂⋅n⎥⎟
#                                               ⎥⎟
#                                               ⎥⎟
#                                               ⎥⎟
#                            2                  ⎥⎟
# ⋅T₂₁₁₁₁⋅m - P₂₂₁₂₂⋅T₂₁₁₁₁⋅n  + P₂₂₁₂₂⋅T₂₁₁₁₁⋅n⎥⎟
#                                               ⎥⎟
#                                               ⎥⎟
#                                               ⎥⎟
#                                               ⎥⎟
#                                               ⎥⎟
#                                               ⎥⎟
#                                               ⎥⎟
#                                               ⎥⎟
#                                               ⎥⎟
#                                               ⎥⎟
#                                               ⎥⎟
#                                               ⎥⎟
#                                               ⎥⎟
#                                               ⎥⎟
#                                               ⎥⎟
#                            2                  ⎥⎟
# ⋅T₂₁₂₁₁⋅m - P₂₁₁₁₁⋅T₂₂₁₁₁⋅n  + P₂₁₁₁₁⋅T₂₂₁₁₁⋅n⎥⎟
#                                               ⎥⎟
#                            2                  ⎥⎟
# ⋅T₂₁₁₁₁⋅m - P₂₂₁₁₁⋅T₂₁₁₁₁⋅n  + P₂₂₁₁₁⋅T₂₁₁₁₁⋅n⎥⎟
#                                               ⎥⎟
# ₁₁₂₁⋅T₂₁₁₁₁)                                  ⎥⎟
#                                               ⎥⎟
#                                               ⎥⎟
#                                               ⎥⎟
#                                               ⎥⎟
#                                               ⎥⎟
#                                               ⎥⎟
#                                               ⎥⎟
#                                               ⎥⎟
#                                               ⎥⎟
#                                               ⎥⎟
#                                               ⎥⎟
#                                               ⎥⎟
#                                               ⎥⎟
#                                               ⎥⎟
#                                               ⎥⎟
#                                               ⎥⎟
#                                               ⎥⎟
#                            2                  ⎥⎟
# ⋅T₂₁₂₂₂⋅m - P₂₁₁₁₁⋅T₂₂₁₂₂⋅n  + P₂₁₁₁₁⋅T₂₂₁₂₂⋅n⎥⎟
#                                               ⎥⎟
#                                               ⎥⎟
#                                               ⎥⎟
#                                               ⎥⎟
#                                               ⎥⎟
#                                               ⎥⎟
#                                               ⎥⎟
#                                               ⎥⎟
#                                               ⎥⎟
#                                               ⎥⎟
#                                               ⎥⎟
#                                               ⎥⎟
#                                               ⎥⎟
#                                               ⎥⎟
#                                               ⎥⎟
#                            2                  ⎥⎟
# ⋅T₂₁₁₁₁⋅m - P₂₂₁₁₁⋅T₂₁₁₁₁⋅n  + P₂₂₁₁₁⋅T₂₁₁₁₁⋅n⎥⎟
#                                               ⎥⎟
#                                               ⎥⎟
#                                               ⎥⎟
#                                               ⎥⎟
#                                               ⎥⎟
#                                               ⎥⎟
#                                               ⎥⎟
#                                               ⎥⎟
#                                               ⎥⎟
#                            2                  ⎥⎟
# ⋅T₂₁₂₁₁⋅m - P₂₂₁₂₂⋅T₂₂₁₁₁⋅n  + P₂₂₁₂₂⋅T₂₂₁₁₁⋅n⎥⎟
#                                               ⎥⎟
#                                               ⎥⎟
#                                               ⎥⎟
#                                               ⎥⎟
#                                               ⎥⎟
#                                               ⎥⎟
#                                               ⎥⎟
#                                               ⎥⎟
#                                               ⎥⎟
#                                               ⎥⎟
#                                               ⎥⎟
#                                               ⎥⎟
#                            2                  ⎥⎟
# ⋅T₂₁₂₂₂⋅m - P₂₂₁₁₁⋅T₂₂₁₂₂⋅n  + P₂₂₁₁₁⋅T₂₂₁₂₂⋅n⎥⎟
#                                               ⎥⎟
#                                               ⎦⎟
#                                                ⎟
#                                                ⎟
#                                                ⎟
#                                                ⎟
#                                                ⎟
#                                                ⎟
#                                                ⎟
#                                                ⎟
#                                                ⎟
#                                                ⎟
#                                                ⎟
#                                                ⎟
#                                                ⎟
#                                                ⎟
#                                                ⎟
#                                                ⎟
#                                                ⎟
#                                                ⎟
#                                                ⎟
#                                                ⎟
#                                                ⎟
#                                                ⎟
#                                                ⎟
#                                                ⎟
#                                                ⎟
#                                                ⎟
#                                                ⎟
#                                                ⎟
#                                                ⎟
#                                                ⎟
#                                                ⎟
#                                                ⎟
#                                                ⎟
#                                                ⎟
#                                                ⎟
#                                                ⎟
#                                                ⎟
#                                                ⎟
#                                                ⎟
#                                                ⎟
#                                                ⎟
#                                                ⎟
#                                                ⎟
#                                                ⎟
#                                                ⎟
#                                                ⎟
#                                                ⎟
#                                                ⎟
#                                                ⎟
#                                                ⎟
#                                                ⎟
#                                                ⎟
#                                                ⎟
#                                                ⎟
#                                                ⎟
#                                                ⎟
#                                                ⎟
#                                                ⎟
#                                                ⎟
#                                                ⎟
#                                                ⎟
#                                                ⎟
#                                                ⎟
#                                                ⎟
#                                                ⎟
#                                                ⎟
#                                                ⎟
#                                                ⎟
#                                                ⎟
#                                                ⎟
#                                                ⎟
#                                                ⎟
#                                                ⎟
#                                                ⎟
#                                                ⎟
#                                                ⎟
#                                                ⎟
#                                                ⎟
#                                                ⎟
#                                                ⎟
#                                                ⎟
#                                                ⎟
#                                                ⎟
#                                                ⎟
#                                                ⎟
#                                                ⎟
#                                                ⎟
#                                                ⎟
#                                                ⎟
#                                                ⎟
#                                                ⎟
#                                                ⎟
#                                                ⎟
#                                                ⎟
#                                                ⎟
#                                                ⎟
#                                                ⎟
#                                                ⎟
#                                                ⎟
#                                                ⎟
#                                                ⎟
#                                                ⎟
#                                                ⎟
#                                                ⎟
#                                                ⎟
#                                                ⎟
#                                                ⎟
#                                                ⎟
#                                                ⎟
#                                                ⎟
#                                                ⎟
#                                                ⎟
#                                                ⎟
#                                                ⎟
#                                                ⎟
#                                                ⎟
#                                                ⎟
#                                                ⎟
#                                                ⎟
#                                                ⎟
#                                                ⎟
#                                                ⎟
#                                                ⎟
#                                                ⎟
#                                                ⎟
#                                                ⎟
#                                                ⎟
#                                                ⎟
#                                                ⎟
#                                                ⎟
#                                                ⎟
#                                                ⎠

# %%
factor(check[ZE[1]*ZE[3]])
# Out:
# (m + n)⋅(r + s)⋅(P₁₁₁₁₁⋅T₁₁₁₁₁ + P₂₁₁₁₁⋅T₂₁₁₁₁)

# %%
factor(check[ZE[2]*ZE[4]])
# Out:
# (m + n)⋅(r + s)⋅(P₁₁₁₁₁⋅T₁₁₁₁₁ + P₂₁₁₁₁⋅T₂₁₁₁₁)

# %%
factor(check[ZE[1]*ZE[3]])

# %% [markdown]
# simbolo = S_component002(2,4,L0,ZE)
# check = poly_args(simbolo,dc,dZE,factor)

# %%
factor(check[ZE[2]*ZE[4]])

# %% [markdown]
# factor(check[ZE[2]*ZE[4]])

# %%
f = zeros(n)
h = zeros(n)


for x in range(0,n):
    for y in range(0,n):
        if x == y: f[x,y]=Function('f')(*ZX)
        if x == y:
            part = 0
            for z in range(1,n+1):
                part = part + p[z-1][z-1]*ZE[z]*ZE[z+n]
            h[x,y]=part
#h[0,0]=(q[0]*ZE[1]*ZE[3]+q[1]*ZE[2]*ZE[4])

# %%
f,h
# Out:
# ⎛⎡f(F, X₁, X₂, Y₁, Y₂)           0          ⎤, ⎡E₁⋅I₁⋅p₁₁ + E₂⋅I₂⋅p₂₂
# ⎜⎢                                          ⎥  ⎢
# ⎝⎣         0            f(F, X₁, X₂, Y₁, Y₂)⎦  ⎣          0            E₁⋅I₁⋅p
#
#    0          ⎤⎞
#               ⎥⎟
# ₁₁ + E₂⋅I₂⋅p₂₂⎦⎠

# %%
LA = []

# %%
S,EQS = poly_difeomorphism(L0,ZE,dc,dZE,h,factor)

# %%
EQS = clean_system00(EQS,n)

# %%
ew = EQS[1,4]
chomp = []
for z in range(1,n+1):
                chomp.append(ZE[z]*ZE[z+n])
chew = EQS[1:1+n,1+n:2*n+1]

tai = []
for x in range(0,n):
    for y in range(0,n):
        if x == y:
            for z in chomp:
                tai.append(factor(chew[x,y][z]))
for x in ew:
    ew[x] = factor(ew[x])
Matrix(list(ew.keys())),Matrix(list(ew.values())),Matrix(tai)
# Out:
# ⎛
# ⎜⎡E₁⋅I₁⎤, ⎡
# ⎜⎢     ⎥  ⎢
# ⎜⎢E₁⋅I₂⎥  ⎢
# ⎜⎢     ⎥  ⎢
# ⎜⎢E₂⋅I₂⎥  ⎢
# ⎜⎢     ⎥  ⎢
# ⎜⎣E₂⋅I₁⎦  ⎢
# ⎜         ⎢
# ⎝         ⎣16⋅P₁₁₁₁₁⋅T₁₁₁₁₁ + 4⋅P₁₁₁₁₁⋅T₁₁₁₁₂ + 4⋅P₁₁₁₁₁⋅T₁₁₁₂₁ + 4⋅P₁₁₁₁₁⋅T₁₂
#
#
#
#
#                        (P₁₁₁₁₁ + P₁₁₁₁₂ + P₁₁₁₂₁ + P₁₁₁₂₂)⋅(T₁₁₁₁₁⋅T₂₁₁₁₂ + T₁
#                        ───────────────────────────────────────────────────────
#
#
#
#
# ₂₁₂ + 4⋅P₁₁₁₁₁⋅T₁₂₂₂₁ + 4⋅P₁₁₂₁₁⋅T₁₁₁₁₁ + P₁₁₂₁₁⋅T₁₁₁₁₂ + P₁₁₂₁₁⋅T₁₁₁₂₁ + P₁₁₂
#
#
#
#
# ₁₁₁₁⋅T₂₁₁₂₁ - 4⋅T₁₁₁₁₁⋅T₂₁₁₂₂ - 4⋅T₁₁₁₁₁⋅T₂₁₂₂₂ - 4⋅T₁₁₁₁₁⋅T₂₂₁₂₂ + T₁₁₁₁₁⋅T₂₂
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
# ₁₁⋅T₁₂₂₁₂ + P₁₁₂₁₁⋅T₁₂₂₂₁ + 4⋅P₁₁₂₂₂⋅T₁₁₁₁₁ + P₁₁₂₂₂⋅T₁₁₁₁₂ + P₁₁₂₂₂⋅T₁₁₁₂₁ +
#
#
#
#
# ₂₁₂ + T₁₁₁₁₁⋅T₂₂₂₂₁ - T₁₁₁₁₂⋅T₂₁₁₁₁ - T₁₁₁₁₂⋅T₂₁₁₂₂ - T₁₁₁₁₂⋅T₂₁₂₂₂ - T₁₁₁₁₂⋅T
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
# P₁₁₂₂₂⋅T₁₂₂₁₂ + P₁₁₂₂₂⋅T₁₂₂₂₁ + 4⋅P₁₂₁₁₁⋅T₁₁₁₁₁ + P₁₂₁₁₁⋅T₁₁₁₁₂ + P₁₂₁₁₁⋅T₁₁₁₂
#
#
#
#
# ₂₂₁₂₂ - T₁₁₁₂₁⋅T₂₁₁₁₁ - T₁₁₁₂₁⋅T₂₁₁₂₂ - T₁₁₁₂₁⋅T₂₁₂₂₂ - T₁₁₁₂₁⋅T₂₂₁₂₂ + 4⋅T₁₁₁
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
# ₁ + P₁₂₁₁₁⋅T₁₂₂₁₂ + P₁₂₁₁₁⋅T₁₂₂₂₁ + 4⋅P₁₂₁₂₂⋅T₁₁₁₁₁ + P₁₂₁₂₂⋅T₁₁₁₁₂ + P₁₂₁₂₂⋅T
#
#
#                                       0
#
# ₂₂⋅T₂₁₁₁₁ + T₁₁₁₂₂⋅T₂₁₁₁₂ + T₁₁₁₂₂⋅T₂₁₁₂₁ + T₁₁₁₂₂⋅T₂₂₂₁₂ + T₁₁₁₂₂⋅T₂₂₂₂₁ + 4⋅
# ──────────────────────────────────────────────────────────────────────────────
#                  4⋅T₂₁₁₁₁ + T₂₁₁₁₂ + T₂₁₁₂₁ + T₂₂₂₁₂ + T₂₂₂₂₁
#
#                                       0
#
# ₁₁₁₂₁ + P₁₂₁₂₂⋅T₁₂₂₁₂ + P₁₂₁₂₂⋅T₁₂₂₂₁ + 16⋅P₂₁₁₁₁⋅T₂₁₁₁₁ + 4⋅P₂₁₁₁₁⋅T₂₁₁₁₂ + 4
#
#
#
#
# T₁₁₂₂₂⋅T₂₁₁₁₁ + T₁₁₂₂₂⋅T₂₁₁₁₂ + T₁₁₂₂₂⋅T₂₁₁₂₁ + T₁₁₂₂₂⋅T₂₂₂₁₂ + T₁₁₂₂₂⋅T₂₂₂₂₁
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
# ⋅P₂₁₁₁₁⋅T₂₁₁₂₁ + 4⋅P₂₁₁₁₁⋅T₂₂₂₁₂ + 4⋅P₂₁₁₁₁⋅T₂₂₂₂₁ + 4⋅P₂₁₂₁₁⋅T₂₁₁₁₁ + P₂₁₂₁₁⋅
#
#
#
#
# + 4⋅T₁₂₁₂₂⋅T₂₁₁₁₁ + T₁₂₁₂₂⋅T₂₁₁₁₂ + T₁₂₁₂₂⋅T₂₁₁₂₁ + T₁₂₁₂₂⋅T₂₂₂₁₂ + T₁₂₁₂₂⋅T₂₂
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
# T₂₁₁₁₂ + P₂₁₂₁₁⋅T₂₁₁₂₁ + P₂₁₂₁₁⋅T₂₂₂₁₂ + P₂₁₂₁₁⋅T₂₂₂₂₁ + 4⋅P₂₁₂₂₂⋅T₂₁₁₁₁ + P₂₁
#
#
#
#
# ₂₂₁ - T₁₂₂₁₂⋅T₂₁₁₁₁ - T₁₂₂₁₂⋅T₂₁₁₂₂ - T₁₂₂₁₂⋅T₂₁₂₂₂ - T₁₂₂₁₂⋅T₂₂₁₂₂ - T₁₂₂₂₁⋅T
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
# ₂₂₂⋅T₂₁₁₁₂ + P₂₁₂₂₂⋅T₂₁₁₂₁ + P₂₁₂₂₂⋅T₂₂₂₁₂ + P₂₁₂₂₂⋅T₂₂₂₂₁ + 4⋅P₂₂₁₁₁⋅T₂₁₁₁₁ +
#
#
#
#
# ₂₁₁₁₁ - T₁₂₂₂₁⋅T₂₁₁₂₂ - T₁₂₂₂₁⋅T₂₁₂₂₂ - T₁₂₂₂₁⋅T₂₂₁₂₂)
# ──────────────────────────────────────────────────────
#
#
#
#
#  P₂₂₁₁₁⋅T₂₁₁₁₂ + P₂₂₁₁₁⋅T₂₁₁₂₁ + P₂₂₁₁₁⋅T₂₂₂₁₂ + P₂₂₁₁₁⋅T₂₂₂₂₁ + 4⋅P₂₂₁₂₂⋅T₂₁₁
#
#                                                                      ⎡8⋅P₁₁₁₁₁
#                                                                   ⎤, ⎢────────
#                                                                   ⎥  ⎢
#                                                                   ⎥  ⎢
#                                                                   ⎥  ⎢
#                                                                   ⎥  ⎢
#                                                                   ⎥  ⎢
#                                                                   ⎥  ⎢
#                                                                   ⎥  ⎣
# ₁₁ + P₂₂₁₂₂⋅T₂₁₁₁₂ + P₂₂₁₂₂⋅T₂₁₁₂₁ + P₂₂₁₂₂⋅T₂₂₂₁₂ + P₂₂₁₂₂⋅T₂₂₂₂₁⎦
#
# ⋅T₁₁₁₁₁⋅T₂₁₁₁₂ + 8⋅P₁₁₁₁₁⋅T₁₁₁₁₁⋅T₂₁₁₂₁ - 32⋅P₁₁₁₁₁⋅T₁₁₁₁₁⋅T₂₁₂₁₁ - 32⋅P₁₁₁₁₁⋅
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#
#
#
#
# T₁₁₁₁₁⋅T₂₂₁₁₁ - 32⋅P₁₁₁₁₁⋅T₁₁₁₁₁⋅T₂₂₂₁₁ + 8⋅P₁₁₁₁₁⋅T₁₁₁₁₁⋅T₂₂₂₁₂ + 8⋅P₁₁₁₁₁⋅T₁
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#
#
#
#
# ₁₁₁₁⋅T₂₂₂₂₁ - 8⋅P₁₁₁₁₁⋅T₁₁₁₁₂⋅T₂₁₁₁₁ - 8⋅P₁₁₁₁₁⋅T₁₁₁₁₂⋅T₂₁₂₁₁ - 8⋅P₁₁₁₁₁⋅T₁₁₁₁
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#
#
#
#
# ₂⋅T₂₂₁₁₁ - 8⋅P₁₁₁₁₁⋅T₁₁₁₁₂⋅T₂₂₂₁₁ - 8⋅P₁₁₁₁₁⋅T₁₁₁₂₁⋅T₂₁₁₁₁ - 8⋅P₁₁₁₁₁⋅T₁₁₁₂₁⋅T
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#
#
#
#
# ₂₁₂₁₁ - 8⋅P₁₁₁₁₁⋅T₁₁₁₂₁⋅T₂₂₁₁₁ - 8⋅P₁₁₁₁₁⋅T₁₁₁₂₁⋅T₂₂₂₁₁ + 32⋅P₁₁₁₁₁⋅T₁₁₂₁₁⋅T₂₁
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#
#
#
#
# ₁₁₁ + 8⋅P₁₁₁₁₁⋅T₁₁₂₁₁⋅T₂₁₁₁₂ + 8⋅P₁₁₁₁₁⋅T₁₁₂₁₁⋅T₂₁₁₂₁ + 8⋅P₁₁₁₁₁⋅T₁₁₂₁₁⋅T₂₂₂₁₂
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#
#
#
#
#  + 8⋅P₁₁₁₁₁⋅T₁₁₂₁₁⋅T₂₂₂₂₁ + 32⋅P₁₁₁₁₁⋅T₁₂₁₁₁⋅T₂₁₁₁₁ + 8⋅P₁₁₁₁₁⋅T₁₂₁₁₁⋅T₂₁₁₁₂ +
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#
#
#
#
#  8⋅P₁₁₁₁₁⋅T₁₂₁₁₁⋅T₂₁₁₂₁ + 8⋅P₁₁₁₁₁⋅T₁₂₁₁₁⋅T₂₂₂₁₂ + 8⋅P₁₁₁₁₁⋅T₁₂₁₁₁⋅T₂₂₂₂₁ + 32
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#
#
#
#
# ⋅P₁₁₁₁₁⋅T₁₂₂₁₁⋅T₂₁₁₁₁ + 8⋅P₁₁₁₁₁⋅T₁₂₂₁₁⋅T₂₁₁₁₂ + 8⋅P₁₁₁₁₁⋅T₁₂₂₁₁⋅T₂₁₁₂₁ + 8⋅P₁
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#
#
#
#
# ₁₁₁₁⋅T₁₂₂₁₁⋅T₂₂₂₁₂ + 8⋅P₁₁₁₁₁⋅T₁₂₂₁₁⋅T₂₂₂₂₁ - 8⋅P₁₁₁₁₁⋅T₁₂₂₁₂⋅T₂₁₁₁₁ - 8⋅P₁₁₁₁
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#
#
#
#
# ₁⋅T₁₂₂₁₂⋅T₂₁₂₁₁ - 8⋅P₁₁₁₁₁⋅T₁₂₂₁₂⋅T₂₂₁₁₁ - 8⋅P₁₁₁₁₁⋅T₁₂₂₁₂⋅T₂₂₂₁₁ - 8⋅P₁₁₁₁₁⋅T
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#
#
#
#
# ₁₂₂₂₁⋅T₂₁₁₁₁ - 8⋅P₁₁₁₁₁⋅T₁₂₂₂₁⋅T₂₁₂₁₁ - 8⋅P₁₁₁₁₁⋅T₁₂₂₂₁⋅T₂₂₁₁₁ - 8⋅P₁₁₁₁₁⋅T₁₂₂
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#
#
#
#
# ₂₁⋅T₂₂₂₁₁ + 8⋅P₁₁₁₁₂⋅T₁₁₁₁₁⋅T₂₁₁₁₂ + 8⋅P₁₁₁₁₂⋅T₁₁₁₁₁⋅T₂₁₁₂₁ - 32⋅P₁₁₁₁₂⋅T₁₁₁₁₁
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#
#
#
#
# ⋅T₂₁₂₁₁ - 32⋅P₁₁₁₁₂⋅T₁₁₁₁₁⋅T₂₂₁₁₁ - 32⋅P₁₁₁₁₂⋅T₁₁₁₁₁⋅T₂₂₂₁₁ + 8⋅P₁₁₁₁₂⋅T₁₁₁₁₁⋅
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#
#
#
#
# T₂₂₂₁₂ + 8⋅P₁₁₁₁₂⋅T₁₁₁₁₁⋅T₂₂₂₂₁ - 8⋅P₁₁₁₁₂⋅T₁₁₁₁₂⋅T₂₁₁₁₁ - 8⋅P₁₁₁₁₂⋅T₁₁₁₁₂⋅T₂₁
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#
#
#
#
# ₂₁₁ - 8⋅P₁₁₁₁₂⋅T₁₁₁₁₂⋅T₂₂₁₁₁ - 8⋅P₁₁₁₁₂⋅T₁₁₁₁₂⋅T₂₂₂₁₁ - 8⋅P₁₁₁₁₂⋅T₁₁₁₂₁⋅T₂₁₁₁₁
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#
#
#
#
#  - 8⋅P₁₁₁₁₂⋅T₁₁₁₂₁⋅T₂₁₂₁₁ - 8⋅P₁₁₁₁₂⋅T₁₁₁₂₁⋅T₂₂₁₁₁ - 8⋅P₁₁₁₁₂⋅T₁₁₁₂₁⋅T₂₂₂₁₁ +
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#
#
#
#
# 32⋅P₁₁₁₁₂⋅T₁₁₂₁₁⋅T₂₁₁₁₁ + 8⋅P₁₁₁₁₂⋅T₁₁₂₁₁⋅T₂₁₁₁₂ + 8⋅P₁₁₁₁₂⋅T₁₁₂₁₁⋅T₂₁₁₂₁ + 8⋅
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#
#
#
#
# P₁₁₁₁₂⋅T₁₁₂₁₁⋅T₂₂₂₁₂ + 8⋅P₁₁₁₁₂⋅T₁₁₂₁₁⋅T₂₂₂₂₁ + 32⋅P₁₁₁₁₂⋅T₁₂₁₁₁⋅T₂₁₁₁₁ + 8⋅P₁
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#
#
#
#
# ₁₁₁₂⋅T₁₂₁₁₁⋅T₂₁₁₁₂ + 8⋅P₁₁₁₁₂⋅T₁₂₁₁₁⋅T₂₁₁₂₁ + 8⋅P₁₁₁₁₂⋅T₁₂₁₁₁⋅T₂₂₂₁₂ + 8⋅P₁₁₁₁
# ──────────────────────────────────────────────────────────────────────────────
#
#
#  32⋅P₁₁₁₁₁⋅T₁₁₁₁₁ + 8⋅P₁₁₁₁₁⋅T₁₁₁₁₂ + 8⋅P₁₁₁₁₁⋅T₁₁₁₂₁ + 8⋅P₁₁₁₁₁⋅T₁₂₂₁₂ + 8⋅P₁
#
#  32⋅P₁₁₁₁₁⋅T₁₁₁₁₁ + 8⋅P₁₁₁₁₁⋅T₁₁₁₁₂ + 8⋅P₁₁₁₁₁⋅T₁₁₁₂₁ + 8⋅P₁₁₁₁₁⋅T₁₂₂₁₂ + 8⋅P₁
#
#
#
#
# ₂⋅T₁₂₁₁₁⋅T₂₂₂₂₁ + 32⋅P₁₁₁₁₂⋅T₁₂₂₁₁⋅T₂₁₁₁₁ + 8⋅P₁₁₁₁₂⋅T₁₂₂₁₁⋅T₂₁₁₁₂ + 8⋅P₁₁₁₁₂⋅
# ──────────────────────────────────────────────────────────────────────────────
#
#
# ₁₁₁₁⋅T₁₂₂₂₁ + 8⋅P₁₁₂₁₁⋅T₁₁₁₁₁ + 2⋅P₁₁₂₁₁⋅T₁₁₁₁₂ + 2⋅P₁₁₂₁₁⋅T₁₁₁₂₁ + 2⋅P₁₁₂₁₁⋅T
#
# ₁₁₁₁⋅T₁₂₂₂₁ + 8⋅P₁₁₂₁₁⋅T₁₁₁₁₁ + 2⋅P₁₁₂₁₁⋅T₁₁₁₁₂ + 2⋅P₁₁₂₁₁⋅T₁₁₁₂₁ + 2⋅P₁₁₂₁₁⋅T
#
#
#
#
# T₁₂₂₁₁⋅T₂₁₁₂₁ + 8⋅P₁₁₁₁₂⋅T₁₂₂₁₁⋅T₂₂₂₁₂ + 8⋅P₁₁₁₁₂⋅T₁₂₂₁₁⋅T₂₂₂₂₁ - 8⋅P₁₁₁₁₂⋅T₁₂
# ──────────────────────────────────────────────────────────────────────────────
#
#
# ₁₂₂₁₂ + 2⋅P₁₁₂₁₁⋅T₁₂₂₂₁ + 8⋅P₁₁₂₂₂⋅T₁₁₁₁₁ + 2⋅P₁₁₂₂₂⋅T₁₁₁₁₂ + 2⋅P₁₁₂₂₂⋅T₁₁₁₂₁
#
# ₁₂₂₁₂ + 2⋅P₁₁₂₁₁⋅T₁₂₂₂₁ + 8⋅P₁₁₂₂₂⋅T₁₁₁₁₁ + 2⋅P₁₁₂₂₂⋅T₁₁₁₁₂ + 2⋅P₁₁₂₂₂⋅T₁₁₁₂₁
#
#         8⋅P₁₁₁₁₁⋅T₁₁₁₁₁ + 8⋅P₁₁₁₁₁⋅T₁₁₁₂₂ + 8⋅P₁₁₁₁₁⋅T₁₁₂₂₂ + 8⋅P₁₁₁₁₁⋅T₁₂₁₂₂
#
#
# ₂₁₂⋅T₂₁₁₁₁ - 8⋅P₁₁₁₁₂⋅T₁₂₂₁₂⋅T₂₁₂₁₁ - 8⋅P₁₁₁₁₂⋅T₁₂₂₁₂⋅T₂₂₁₁₁ - 8⋅P₁₁₁₁₂⋅T₁₂₂₁₂
# ──────────────────────────────────────────────────────────────────────────────
#
#
# + 2⋅P₁₁₂₂₂⋅T₁₂₂₁₂ + 2⋅P₁₁₂₂₂⋅T₁₂₂₂₁ + 8⋅P₁₂₁₁₁⋅T₁₁₁₁₁ + 2⋅P₁₂₁₁₁⋅T₁₁₁₁₂ + 2⋅P₁
#
# + 2⋅P₁₁₂₂₂⋅T₁₂₂₁₂ + 2⋅P₁₁₂₂₂⋅T₁₂₂₂₁ + 8⋅P₁₂₁₁₁⋅T₁₁₁₁₁ + 2⋅P₁₂₁₁₁⋅T₁₁₁₁₂ + 2⋅P₁
#
# + 8⋅P₁₂₂₁₁⋅T₁₁₁₁₁ + 8⋅P₁₂₂₁₁⋅T₁₁₁₂₂ + 8⋅P₁₂₂₁₁⋅T₁₁₂₂₂ + 8⋅P₁₂₂₁₁⋅T₁₂₁₂₂ + 8⋅P₁
#
#
# ⋅T₂₂₂₁₁ - 8⋅P₁₁₁₁₂⋅T₁₂₂₂₁⋅T₂₁₁₁₁ - 8⋅P₁₁₁₁₂⋅T₁₂₂₂₁⋅T₂₁₂₁₁ - 8⋅P₁₁₁₁₂⋅T₁₂₂₂₁⋅T₂
# ──────────────────────────────────────────────────────────────────────────────
#
#
# ₂₁₁₁⋅T₁₁₁₂₁ + 2⋅P₁₂₁₁₁⋅T₁₂₂₁₂ + 2⋅P₁₂₁₁₁⋅T₁₂₂₂₁ + 8⋅P₁₂₁₂₂⋅T₁₁₁₁₁ + 2⋅P₁₂₁₂₂⋅T
#
# ₂₁₁₁⋅T₁₁₁₂₁ + 2⋅P₁₂₁₁₁⋅T₁₂₂₁₂ + 2⋅P₁₂₁₁₁⋅T₁₂₂₂₁ + 8⋅P₁₂₁₂₂⋅T₁₁₁₁₁ + 2⋅P₁₂₁₂₂⋅T
#
# ₂₂₁₂⋅T₁₁₁₁₁ + 8⋅P₁₂₂₁₂⋅T₁₁₁₂₂ + 8⋅P₁₂₂₁₂⋅T₁₁₂₂₂ + 8⋅P₁₂₂₁₂⋅T₁₂₁₂₂ + 8⋅P₁₂₂₂₁⋅T
#
#
# ₂₁₁₁ - 8⋅P₁₁₁₁₂⋅T₁₂₂₂₁⋅T₂₂₂₁₁ + 8⋅P₁₁₁₂₁⋅T₁₁₁₁₁⋅T₂₁₁₁₂ + 8⋅P₁₁₁₂₁⋅T₁₁₁₁₁⋅T₂₁₁₂
# ──────────────────────────────────────────────────────────────────────────────
#                                           4⋅T₂₁₁₁₁ + T₂₁₁₁₂ + T₂₁₁₂₁ + T₂₂₂₁₂
#
# ₁₁₁₁₂ + 2⋅P₁₂₁₂₂⋅T₁₁₁₂₁ + 2⋅P₁₂₁₂₂⋅T₁₂₂₁₂ + 2⋅P₁₂₁₂₂⋅T₁₂₂₂₁ + 32⋅P₂₁₁₁₁⋅T₂₁₁₁₁
#
# ₁₁₁₁₂ + 2⋅P₁₂₁₂₂⋅T₁₁₁₂₁ + 2⋅P₁₂₁₂₂⋅T₁₂₂₁₂ + 2⋅P₁₂₁₂₂⋅T₁₂₂₂₁ + 32⋅P₂₁₁₁₁⋅T₂₁₁₁₁
#
# ₁₁₁₁₁ + 8⋅P₁₂₂₂₁⋅T₁₁₁₂₂ + 8⋅P₁₂₂₂₁⋅T₁₁₂₂₂ + 8⋅P₁₂₂₂₁⋅T₁₂₁₂₂ + 8⋅P₂₁₁₁₁⋅T₂₁₁₁₁
#
#
# ₁ - 32⋅P₁₁₁₂₁⋅T₁₁₁₁₁⋅T₂₁₂₁₁ - 32⋅P₁₁₁₂₁⋅T₁₁₁₁₁⋅T₂₂₁₁₁ - 32⋅P₁₁₁₂₁⋅T₁₁₁₁₁⋅T₂₂₂₁
# ──────────────────────────────────────────────────────────────────────────────
# + T₂₂₂₂₁
#
#  + 8⋅P₂₁₁₁₁⋅T₂₁₁₁₂ + 8⋅P₂₁₁₁₁⋅T₂₁₁₂₁ + 8⋅P₂₁₁₁₁⋅T₂₂₂₁₂ + 8⋅P₂₁₁₁₁⋅T₂₂₂₂₁ + 8⋅P
#
#  + 8⋅P₂₁₁₁₁⋅T₂₁₁₁₂ + 8⋅P₂₁₁₁₁⋅T₂₁₁₂₁ + 8⋅P₂₁₁₁₁⋅T₂₂₂₁₂ + 8⋅P₂₁₁₁₁⋅T₂₂₂₂₁ + 8⋅P
#
# + 8⋅P₂₁₁₁₁⋅T₂₁₁₂₂ + 8⋅P₂₁₁₁₁⋅T₂₁₂₂₂ + 8⋅P₂₁₁₁₁⋅T₂₂₁₂₂ + 8⋅P₂₂₂₁₁⋅T₂₁₁₁₁ + 8⋅P₂
#
#
# ₁ + 8⋅P₁₁₁₂₁⋅T₁₁₁₁₁⋅T₂₂₂₁₂ + 8⋅P₁₁₁₂₁⋅T₁₁₁₁₁⋅T₂₂₂₂₁ - 8⋅P₁₁₁₂₁⋅T₁₁₁₁₂⋅T₂₁₁₁₁ -
# ──────────────────────────────────────────────────────────────────────────────
#
#
# ₂₁₂₁₁⋅T₂₁₁₁₁ + 2⋅P₂₁₂₁₁⋅T₂₁₁₁₂ + 2⋅P₂₁₂₁₁⋅T₂₁₁₂₁ + 2⋅P₂₁₂₁₁⋅T₂₂₂₁₂ + 2⋅P₂₁₂₁₁⋅
#
# ₂₁₂₁₁⋅T₂₁₁₁₁ + 2⋅P₂₁₂₁₁⋅T₂₁₁₁₂ + 2⋅P₂₁₂₁₁⋅T₂₁₁₂₁ + 2⋅P₂₁₂₁₁⋅T₂₂₂₁₂ + 2⋅P₂₁₂₁₁⋅
#
# ₂₂₁₁⋅T₂₁₁₂₂ + 8⋅P₂₂₂₁₁⋅T₂₁₂₂₂ + 8⋅P₂₂₂₁₁⋅T₂₂₁₂₂ + 8⋅P₂₂₂₁₂⋅T₂₁₁₁₁ + 8⋅P₂₂₂₁₂⋅T
#
#
#  8⋅P₁₁₁₂₁⋅T₁₁₁₁₂⋅T₂₁₂₁₁ - 8⋅P₁₁₁₂₁⋅T₁₁₁₁₂⋅T₂₂₁₁₁ - 8⋅P₁₁₁₂₁⋅T₁₁₁₁₂⋅T₂₂₂₁₁ - 8⋅
# ──────────────────────────────────────────────────────────────────────────────
#
#
# T₂₂₂₂₁ + 8⋅P₂₁₂₂₂⋅T₂₁₁₁₁ + 2⋅P₂₁₂₂₂⋅T₂₁₁₁₂ + 2⋅P₂₁₂₂₂⋅T₂₁₁₂₁ + 2⋅P₂₁₂₂₂⋅T₂₂₂₁₂
#
# T₂₂₂₂₁ + 8⋅P₂₁₂₂₂⋅T₂₁₁₁₁ + 2⋅P₂₁₂₂₂⋅T₂₁₁₁₂ + 2⋅P₂₁₂₂₂⋅T₂₁₁₂₁ + 2⋅P₂₁₂₂₂⋅T₂₂₂₁₂
#
# ₂₁₁₂₂ + 8⋅P₂₂₂₁₂⋅T₂₁₂₂₂ + 8⋅P₂₂₂₁₂⋅T₂₂₁₂₂ + 8⋅P₂₂₂₂₁⋅T₂₁₁₁₁ + 8⋅P₂₂₂₂₁⋅T₂₁₁₂₂
#
#
# P₁₁₁₂₁⋅T₁₁₁₂₁⋅T₂₁₁₁₁ - 8⋅P₁₁₁₂₁⋅T₁₁₁₂₁⋅T₂₁₂₁₁ - 8⋅P₁₁₁₂₁⋅T₁₁₁₂₁⋅T₂₂₁₁₁ - 8⋅P₁₁
# ──────────────────────────────────────────────────────────────────────────────
#
#
#  + 2⋅P₂₁₂₂₂⋅T₂₂₂₂₁ + 8⋅P₂₂₁₁₁⋅T₂₁₁₁₁ + 2⋅P₂₂₁₁₁⋅T₂₁₁₁₂ + 2⋅P₂₂₁₁₁⋅T₂₁₁₂₁ + 2⋅P
#
#  + 2⋅P₂₁₂₂₂⋅T₂₂₂₂₁ + 8⋅P₂₂₁₁₁⋅T₂₁₁₁₁ + 2⋅P₂₂₁₁₁⋅T₂₁₁₁₂ + 2⋅P₂₂₁₁₁⋅T₂₁₁₂₁ + 2⋅P
#
# + 8⋅P₂₂₂₂₁⋅T₂₁₂₂₂ + 8⋅P₂₂₂₂₁⋅T₂₂₁₂₂ - p₂₂
#
#
# ₁₂₁⋅T₁₁₁₂₁⋅T₂₂₂₁₁ + 32⋅P₁₁₁₂₁⋅T₁₁₂₁₁⋅T₂₁₁₁₁ + 8⋅P₁₁₁₂₁⋅T₁₁₂₁₁⋅T₂₁₁₁₂ + 8⋅P₁₁₁₂
# ──────────────────────────────────────────────────────────────────────────────
#
#
# ₂₂₁₁₁⋅T₂₂₂₁₂ + 2⋅P₂₂₁₁₁⋅T₂₂₂₂₁ + 8⋅P₂₂₁₂₂⋅T₂₁₁₁₁ + 2⋅P₂₂₁₂₂⋅T₂₁₁₁₂ + 2⋅P₂₂₁₂₂⋅
#
# ₂₂₁₁₁⋅T₂₂₂₁₂ + 2⋅P₂₂₁₁₁⋅T₂₂₂₂₁ + 8⋅P₂₂₁₂₂⋅T₂₁₁₁₁ + 2⋅P₂₂₁₂₂⋅T₂₁₁₁₂ + 2⋅P₂₂₁₂₂⋅
#
#
#
#
# ₁⋅T₁₁₂₁₁⋅T₂₁₁₂₁ + 8⋅P₁₁₁₂₁⋅T₁₁₂₁₁⋅T₂₂₂₁₂ + 8⋅P₁₁₁₂₁⋅T₁₁₂₁₁⋅T₂₂₂₂₁ + 32⋅P₁₁₁₂₁⋅
# ──────────────────────────────────────────────────────────────────────────────
#
#
# T₂₁₁₂₁ + 2⋅P₂₂₁₂₂⋅T₂₂₂₁₂ + 2⋅P₂₂₁₂₂⋅T₂₂₂₂₁ - p₂₂
#
# T₂₁₁₂₁ + 2⋅P₂₂₁₂₂⋅T₂₂₂₁₂ + 2⋅P₂₂₁₂₂⋅T₂₂₂₂₁ - p₁₁
#
#
#
#
# T₁₂₁₁₁⋅T₂₁₁₁₁ + 8⋅P₁₁₁₂₁⋅T₁₂₁₁₁⋅T₂₁₁₁₂ + 8⋅P₁₁₁₂₁⋅T₁₂₁₁₁⋅T₂₁₁₂₁ + 8⋅P₁₁₁₂₁⋅T₁₂
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#
#
#
#
# ₁₁₁⋅T₂₂₂₁₂ + 8⋅P₁₁₁₂₁⋅T₁₂₁₁₁⋅T₂₂₂₂₁ + 32⋅P₁₁₁₂₁⋅T₁₂₂₁₁⋅T₂₁₁₁₁ + 8⋅P₁₁₁₂₁⋅T₁₂₂₁
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#
#
#
#
# ₁⋅T₂₁₁₁₂ + 8⋅P₁₁₁₂₁⋅T₁₂₂₁₁⋅T₂₁₁₂₁ + 8⋅P₁₁₁₂₁⋅T₁₂₂₁₁⋅T₂₂₂₁₂ + 8⋅P₁₁₁₂₁⋅T₁₂₂₁₁⋅T
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#
#
#
#
# ₂₂₂₂₁ - 8⋅P₁₁₁₂₁⋅T₁₂₂₁₂⋅T₂₁₁₁₁ - 8⋅P₁₁₁₂₁⋅T₁₂₂₁₂⋅T₂₁₂₁₁ - 8⋅P₁₁₁₂₁⋅T₁₂₂₁₂⋅T₂₂₁
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#
#
#
#
# ₁₁ - 8⋅P₁₁₁₂₁⋅T₁₂₂₁₂⋅T₂₂₂₁₁ - 8⋅P₁₁₁₂₁⋅T₁₂₂₂₁⋅T₂₁₁₁₁ - 8⋅P₁₁₁₂₁⋅T₁₂₂₂₁⋅T₂₁₂₁₁
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#
#
#
#
# - 8⋅P₁₁₁₂₁⋅T₁₂₂₂₁⋅T₂₂₁₁₁ - 8⋅P₁₁₁₂₁⋅T₁₂₂₂₁⋅T₂₂₂₁₁ + 8⋅P₁₁₁₂₂⋅T₁₁₁₁₁⋅T₂₁₁₁₂ + 8
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#
#
#
#
# ⋅P₁₁₁₂₂⋅T₁₁₁₁₁⋅T₂₁₁₂₁ - 32⋅P₁₁₁₂₂⋅T₁₁₁₁₁⋅T₂₁₂₁₁ - 32⋅P₁₁₁₂₂⋅T₁₁₁₁₁⋅T₂₂₁₁₁ - 32
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#
#
#
#
# ⋅P₁₁₁₂₂⋅T₁₁₁₁₁⋅T₂₂₂₁₁ + 8⋅P₁₁₁₂₂⋅T₁₁₁₁₁⋅T₂₂₂₁₂ + 8⋅P₁₁₁₂₂⋅T₁₁₁₁₁⋅T₂₂₂₂₁ - 8⋅P₁
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#
#
#
#
# ₁₁₂₂⋅T₁₁₁₁₂⋅T₂₁₁₁₁ - 8⋅P₁₁₁₂₂⋅T₁₁₁₁₂⋅T₂₁₂₁₁ - 8⋅P₁₁₁₂₂⋅T₁₁₁₁₂⋅T₂₂₁₁₁ - 8⋅P₁₁₁₂
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#
#
#
#
# ₂⋅T₁₁₁₁₂⋅T₂₂₂₁₁ - 8⋅P₁₁₁₂₂⋅T₁₁₁₂₁⋅T₂₁₁₁₁ - 8⋅P₁₁₁₂₂⋅T₁₁₁₂₁⋅T₂₁₂₁₁ - 8⋅P₁₁₁₂₂⋅T
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#
#
#
#
# ₁₁₁₂₁⋅T₂₂₁₁₁ - 8⋅P₁₁₁₂₂⋅T₁₁₁₂₁⋅T₂₂₂₁₁ + 32⋅P₁₁₁₂₂⋅T₁₁₂₁₁⋅T₂₁₁₁₁ + 8⋅P₁₁₁₂₂⋅T₁₁
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#
#
#
#
# ₂₁₁⋅T₂₁₁₁₂ + 8⋅P₁₁₁₂₂⋅T₁₁₂₁₁⋅T₂₁₁₂₁ + 8⋅P₁₁₁₂₂⋅T₁₁₂₁₁⋅T₂₂₂₁₂ + 8⋅P₁₁₁₂₂⋅T₁₁₂₁₁
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#
#
#
#
# ⋅T₂₂₂₂₁ + 32⋅P₁₁₁₂₂⋅T₁₂₁₁₁⋅T₂₁₁₁₁ + 8⋅P₁₁₁₂₂⋅T₁₂₁₁₁⋅T₂₁₁₁₂ + 8⋅P₁₁₁₂₂⋅T₁₂₁₁₁⋅T
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#
#
#
#
# ₂₁₁₂₁ + 8⋅P₁₁₁₂₂⋅T₁₂₁₁₁⋅T₂₂₂₁₂ + 8⋅P₁₁₁₂₂⋅T₁₂₁₁₁⋅T₂₂₂₂₁ + 32⋅P₁₁₁₂₂⋅T₁₂₂₁₁⋅T₂₁
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#
#
#
#
# ₁₁₁ + 8⋅P₁₁₁₂₂⋅T₁₂₂₁₁⋅T₂₁₁₁₂ + 8⋅P₁₁₁₂₂⋅T₁₂₂₁₁⋅T₂₁₁₂₁ + 8⋅P₁₁₁₂₂⋅T₁₂₂₁₁⋅T₂₂₂₁₂
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#
#
#
#
#  + 8⋅P₁₁₁₂₂⋅T₁₂₂₁₁⋅T₂₂₂₂₁ - 8⋅P₁₁₁₂₂⋅T₁₂₂₁₂⋅T₂₁₁₁₁ - 8⋅P₁₁₁₂₂⋅T₁₂₂₁₂⋅T₂₁₂₁₁ -
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#
#
#
#
# 8⋅P₁₁₁₂₂⋅T₁₂₂₁₂⋅T₂₂₁₁₁ - 8⋅P₁₁₁₂₂⋅T₁₂₂₁₂⋅T₂₂₂₁₁ - 8⋅P₁₁₁₂₂⋅T₁₂₂₂₁⋅T₂₁₁₁₁ - 8⋅P
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#
#
#
#
# ₁₁₁₂₂⋅T₁₂₂₂₁⋅T₂₁₂₁₁ - 8⋅P₁₁₁₂₂⋅T₁₂₂₂₁⋅T₂₂₁₁₁ - 8⋅P₁₁₁₂₂⋅T₁₂₂₂₁⋅T₂₂₂₁₁ - 4⋅T₂₁₁
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#
#
#
#
# ₁₁⋅p₁₁ - T₂₁₁₁₂⋅p₁₁ - T₂₁₁₂₁⋅p₁₁ - T₂₂₂₁₂⋅p₁₁ - T₂₂₂₂₁⋅p₁₁⎤⎞
# ──────────────────────────────────────────────────────────⎥⎟
#                                                           ⎥⎟
#                                                           ⎥⎟
#                                                           ⎥⎟
#                                                           ⎥⎟
#                                                           ⎥⎟
#                                                           ⎥⎟
#                                                           ⎦⎟
#                                                            ⎠

# %%
# all_sol = solve_pair(EQS[1,3],EQS[2,4],factor)

# %%
all_sol = solve_part(ew,simplify,[])

# %%
all_sol
# Out:
# ⎧        -(16⋅P₁₁₁₁₁⋅T₁₁₁₁₁ + 4⋅P₁₁₁₁₁⋅T₁₁₁₁₂ + 4⋅P₁₁₁₁₁⋅T₁₁₁₂₁ + 4⋅P₁₁₁₁₁⋅T₁₂
# ⎨P₁₁₂₂₂: ─────────────────────────────────────────────────────────────────────
# ⎩
#
# ₂₁₂ + 4⋅P₁₁₁₁₁⋅T₁₂₂₂₁ + 4⋅P₁₁₂₁₁⋅T₁₁₁₁₁ + P₁₁₂₁₁⋅T₁₁₁₁₂ + P₁₁₂₁₁⋅T₁₁₁₂₁ + P₁₁₂
# ──────────────────────────────────────────────────────────────────────────────
#
#
# ₁₁⋅T₁₂₂₁₂ + P₁₁₂₁₁⋅T₁₂₂₂₁ + 4⋅P₁₂₁₁₁⋅T₁₁₁₁₁ + P₁₂₁₁₁⋅T₁₁₁₁₂ + P₁₂₁₁₁⋅T₁₁₁₂₁ +
# ──────────────────────────────────────────────────────────────────────────────
#
#
# P₁₂₁₁₁⋅T₁₂₂₁₂ + P₁₂₁₁₁⋅T₁₂₂₂₁ + 4⋅P₁₂₁₂₂⋅T₁₁₁₁₁ + P₁₂₁₂₂⋅T₁₁₁₁₂ + P₁₂₁₂₂⋅T₁₁₁₂
# ──────────────────────────────────────────────────────────────────────────────
#
#
# ₁ + P₁₂₁₂₂⋅T₁₂₂₁₂ + P₁₂₁₂₂⋅T₁₂₂₂₁ + 16⋅P₂₁₁₁₁⋅T₂₁₁₁₁ + 4⋅P₂₁₁₁₁⋅T₂₁₁₁₂ + 4⋅P₂₁
# ──────────────────────────────────────────────────────────────────────────────
#                                                       4⋅T₁₁₁₁₁ + T₁₁₁₁₂ + T₁₁₁
#
# ₁₁₁⋅T₂₁₁₂₁ + 4⋅P₂₁₁₁₁⋅T₂₂₂₁₂ + 4⋅P₂₁₁₁₁⋅T₂₂₂₂₁ + 4⋅P₂₁₂₁₁⋅T₂₁₁₁₁ + P₂₁₂₁₁⋅T₂₁₁
# ──────────────────────────────────────────────────────────────────────────────
# ₂₁ + T₁₂₂₁₂ + T₁₂₂₂₁
#
# ₁₂ + P₂₁₂₁₁⋅T₂₁₁₂₁ + P₂₁₂₁₁⋅T₂₂₂₁₂ + P₂₁₂₁₁⋅T₂₂₂₂₁ + 4⋅P₂₁₂₂₂⋅T₂₁₁₁₁ + P₂₁₂₂₂⋅
# ──────────────────────────────────────────────────────────────────────────────
#
#
# T₂₁₁₁₂ + P₂₁₂₂₂⋅T₂₁₁₂₁ + P₂₁₂₂₂⋅T₂₂₂₁₂ + P₂₁₂₂₂⋅T₂₂₂₂₁ + 4⋅P₂₂₁₁₁⋅T₂₁₁₁₁ + P₂₂
# ──────────────────────────────────────────────────────────────────────────────
#
#
# ₁₁₁⋅T₂₁₁₁₂ + P₂₂₁₁₁⋅T₂₁₁₂₁ + P₂₂₁₁₁⋅T₂₂₂₁₂ + P₂₂₁₁₁⋅T₂₂₂₂₁ + 4⋅P₂₂₁₂₂⋅T₂₁₁₁₁ +
# ──────────────────────────────────────────────────────────────────────────────
#
#
#  P₂₂₁₂₂⋅T₂₁₁₁₂ + P₂₂₁₂₂⋅T₂₁₁₂₁ + P₂₂₁₂₂⋅T₂₂₂₁₂ + P₂₂₁₂₂⋅T₂₂₂₂₁)           T₁₁₁
# ────────────────────────────────────────────────────────────────, T₂₂₁₂₂: ────
#
#
# ₁₁⋅T₂₁₁₁₂ + T₁₁₁₁₁⋅T₂₁₁₂₁ - 4⋅T₁₁₁₁₁⋅T₂₁₁₂₂ - 4⋅T₁₁₁₁₁⋅T₂₁₂₂₂ + T₁₁₁₁₁⋅T₂₂₂₁₂
# ──────────────────────────────────────────────────────────────────────────────
#
#
# + T₁₁₁₁₁⋅T₂₂₂₂₁ - T₁₁₁₁₂⋅T₂₁₁₁₁ - T₁₁₁₁₂⋅T₂₁₁₂₂ - T₁₁₁₁₂⋅T₂₁₂₂₂ - T₁₁₁₂₁⋅T₂₁₁₁
# ──────────────────────────────────────────────────────────────────────────────
#
#
# ₁ - T₁₁₁₂₁⋅T₂₁₁₂₂ - T₁₁₁₂₁⋅T₂₁₂₂₂ + 4⋅T₁₁₁₂₂⋅T₂₁₁₁₁ + T₁₁₁₂₂⋅T₂₁₁₁₂ + T₁₁₁₂₂⋅T
# ──────────────────────────────────────────────────────────────────────────────
#
#
# ₂₁₁₂₁ + T₁₁₁₂₂⋅T₂₂₂₁₂ + T₁₁₁₂₂⋅T₂₂₂₂₁ + 4⋅T₁₁₂₂₂⋅T₂₁₁₁₁ + T₁₁₂₂₂⋅T₂₁₁₁₂ + T₁₁₂
# ──────────────────────────────────────────────────────────────────────────────
#         4⋅T₁₁₁₁₁ + T₁₁₁₁₂ + T₁₁₁₂₁ + T₁₂₂₁₂ + T₁₂₂₂₁
#
# ₂₂⋅T₂₁₁₂₁ + T₁₁₂₂₂⋅T₂₂₂₁₂ + T₁₁₂₂₂⋅T₂₂₂₂₁ + 4⋅T₁₂₁₂₂⋅T₂₁₁₁₁ + T₁₂₁₂₂⋅T₂₁₁₁₂ +
# ──────────────────────────────────────────────────────────────────────────────
#
#
# T₁₂₁₂₂⋅T₂₁₁₂₁ + T₁₂₁₂₂⋅T₂₂₂₁₂ + T₁₂₁₂₂⋅T₂₂₂₂₁ - T₁₂₂₁₂⋅T₂₁₁₁₁ - T₁₂₂₁₂⋅T₂₁₁₂₂
# ──────────────────────────────────────────────────────────────────────────────
#
#
# - T₁₂₂₁₂⋅T₂₁₂₂₂ - T₁₂₂₂₁⋅T₂₁₁₁₁ - T₁₂₂₂₁⋅T₂₁₁₂₂ - T₁₂₂₂₁⋅T₂₁₂₂₂⎫
# ───────────────────────────────────────────────────────────────⎬
#                                                                ⎭

# %%
passe = 0
L1 = L0[:]
LA.append(L1)
tabix = 0
for x in all_sol:
    subs_e = {}
    subs_e[x] = all_sol[x]
    if tabix == passe:
        for x in range(0,len(L0)):
            L0[x] = L0[x].subs(subs_e)
       
       
    
    tabix = tabix + 1

# %%
len(LA)
# Out:
# 2

# %%
S,EQS = poly_difeomorphism(L0,ZE,dc,dZE,h,expand)
EQS = clean_system00(EQS,n)
beep(sys.argv[1])

# %%
L0 = LA[-1]

# %%
f[0,0] = 1/S[1,2]
f,h

# %%
H1,S1 = difeomorphism_equations005(L0,ZE,expand,f,h,0,2*n+1)

# %%
S1

# %%
check_me = []
difeo_eqs = []
LD = []
LD.append(L0)
D_LD = []
D_LD.append(0)

for i in range(0,len(LD)):
    Z0 = LD[i]
    H=[]
    S = zeros(n)
    H,S = difeomorphism_equations002(Z0,ZE,simplify,f,h,0,2*n+1)
    
    mixed_test = []
    t3 = 0
    t1 = t2 = 1
    for x in range(0,2*n+1):
        for y in range(x,2*n+1):
            if x != y:
                t1 = simplify(diff(H[x][1],ZE[y]))
                t2 = simplify(diff(H[y][1],ZE[x]))
                d1 = diff(H[x][0],ZE[y])
                d2 = diff(H[y][0],ZE[x])
                t3 = t3 + t1 + t2
                mixed_test.append((t1,t2))
    if t3 != 0:
        difeo_eqs.append((S,H,Z0,D_LD[i],f))
        check_me.append(mixed_test)

# %%
check_me

# %%
difeo_eqs[0][1]

# %%
L0 = L1

# %%
CM_LD = contactomorphism_equations(L0,ZE,expand,f)
Ja = Matrix(L0).jacobian(ZE)
DeJ = Ja.berkowitz_det()
for x in range(0,2*n+1):
    DeJ = DeJ.subs([(diff(L0[0],ZE[x]),CM_LD[x])])

# %%
for x in range(0,2*n+1):
    Ja = Ja.subs([(diff(L0[0],ZE[x]),CM_LD[x])])
simplify(Ja)

# %%
DeJ = simplify(DeJ)

# %%
CM_LD

# %%
Matrix(L0)

# %%
all_sol = {}
exclude = [ZE[1]*ZE[3],ZE[2]*ZE[4]]
for x in range(0,n):
    for y in range(0,n):
        if x != y:
            ambar = list(EQIE[x,y].values())
        else:
            ambar = []
            if x == 0:
                for i in EQIE[x,y]:
                    if i not in exclude :
                        ambar.append(EQIE[x,y][i])
        if len(all_sol) > 1:
            ambar = []
        for z in ambar:
                fs = list(z.free_symbols)
                for w in fs:
                    sol = solve(z,w,dict=True)
                    if list(sol[0].keys())[0] not in all_sol.keys():
                        all_sol.update(sol[0])
                        break

# %%
S,EQS = poly_difeomorphism(L0,ZE,dc,dZE,h,factor)

# %%
EQS = clean_system00(EQS,n)

# %%
EQS

# %%
EQS[1:1+n,1+n:2*n+1]

# %%
EQS[1:1+n,1:n+1]
# Out:
# ⎡{}  {}⎤
# ⎢      ⎥
# ⎣0   {}⎦

# %%
EQS[1+n:2*n+1,n+1:2*n+1]
# Out:
# ⎡{}  {}⎤
# ⎢      ⎥
# ⎣0   {}⎦

# %%
for x in range(0,2*n+1):
    for y in range(0,2*n+1):
        S[x,y] = (S[x,y])

# %%
EQS[1,3]
# Out:
# {E₁⋅I₁: 8⋅P₁₁₁₁₁⋅T₁₁₁₁₁ + 8⋅P₁₁₁₁₁⋅T₁₁₂₁₁ + 8⋅P₁₁₁₁₁⋅T₁₂₁₁₁ + 8⋅P₁₁₁₁₁⋅T₁₂₂₁₁
# + 8⋅P₁₁₁₁₂⋅T₁₁₁₁₁ + 8⋅P₁₁₁₁₂⋅T₁₁₂₁₁ + 8⋅P₁₁₁₁₂⋅T₁₂₁₁₁ + 8⋅P₁₁₁₁₂⋅T₁₂₂₁₁ + 8⋅P₁
# ₁₁₂₁⋅T₁₁₁₁₁ + 8⋅P₁₁₁₂₁⋅T₁₁₂₁₁ + 8⋅P₁₁₁₂₁⋅T₁₂₁₁₁ + 8⋅P₁₁₁₂₁⋅T₁₂₂₁₁ + 8⋅P₁₁₁₂₂⋅T
# ₁₁₁₁₁ + 8⋅P₁₁₁₂₂⋅T₁₁₂₁₁ + 8⋅P₁₁₁₂₂⋅T₁₂₁₁₁ + 8⋅P₁₁₁₂₂⋅T₁₂₂₁₁ + 8⋅P₂₁₁₁₁⋅T₂₁₁₁₁
# + 8⋅P₂₁₁₁₁⋅T₂₁₂₁₁ + 8⋅P₂₁₁₁₁⋅T₂₂₁₁₁ + 8⋅P₂₁₁₁₁⋅T₂₂₂₁₁ + 8⋅P₂₁₁₁₂⋅T₂₁₁₁₁ + 8⋅P₂
# ₁₁₁₂⋅T₂₁₂₁₁ + 8⋅P₂₁₁₁₂⋅T₂₂₁₁₁ + 8⋅P₂₁₁₁₂⋅T₂₂₂₁₁ + 8⋅P₂₁₁₂₁⋅T₂₁₁₁₁ + 8⋅P₂₁₁₂₁⋅T
# ₂₁₂₁₁ + 8⋅P₂₁₁₂₁⋅T₂₂₁₁₁ + 8⋅P₂₁₁₂₁⋅T₂₂₂₁₁ + 8⋅P₂₁₁₂₂⋅T₂₁₁₁₁ + 8⋅P₂₁₁₂₂⋅T₂₁₂₁₁
# + 8⋅P₂₁₁₂₂⋅T₂₂₁₁₁ + 8⋅P₂₁₁₂₂⋅T₂₂₂₁₁ - p₁₁, E₁⋅I₂: 0, E₂⋅I₁: 0, E₂⋅I₂: 32⋅P₁₁₁₁
# ₁⋅T₁₁₁₁₁ + 8⋅P₁₁₁₁₁⋅T₁₁₁₁₂ + 8⋅P₁₁₁₁₁⋅T₁₁₁₂₁ + 8⋅P₁₁₁₁₁⋅T₁₂₂₁₂ + 8⋅P₁₁₁₁₁⋅T₁₂₂
# ₂₁ + 8⋅P₁₁₂₁₁⋅T₁₁₁₁₁ + 2⋅P₁₁₂₁₁⋅T₁₁₁₁₂ + 2⋅P₁₁₂₁₁⋅T₁₁₁₂₁ + 2⋅P₁₁₂₁₁⋅T₁₂₂₁₂ + 2
# ⋅P₁₁₂₁₁⋅T₁₂₂₂₁ + 8⋅P₁₁₂₂₂⋅T₁₁₁₁₁ + 2⋅P₁₁₂₂₂⋅T₁₁₁₁₂ + 2⋅P₁₁₂₂₂⋅T₁₁₁₂₁ + 2⋅P₁₁₂₂
# ₂⋅T₁₂₂₁₂ + 2⋅P₁₁₂₂₂⋅T₁₂₂₂₁ + 8⋅P₁₂₁₁₁⋅T₁₁₁₁₁ + 2⋅P₁₂₁₁₁⋅T₁₁₁₁₂ + 2⋅P₁₂₁₁₁⋅T₁₁₁
# ₂₁ + 2⋅P₁₂₁₁₁⋅T₁₂₂₁₂ + 2⋅P₁₂₁₁₁⋅T₁₂₂₂₁ + 8⋅P₁₂₁₂₂⋅T₁₁₁₁₁ + 2⋅P₁₂₁₂₂⋅T₁₁₁₁₂ + 2
# ⋅P₁₂₁₂₂⋅T₁₁₁₂₁ + 2⋅P₁₂₁₂₂⋅T₁₂₂₁₂ + 2⋅P₁₂₁₂₂⋅T₁₂₂₂₁ + 32⋅P₂₁₁₁₁⋅T₂₁₁₁₁ + 8⋅P₂₁₁
# ₁₁⋅T₂₁₁₁₂ + 8⋅P₂₁₁₁₁⋅T₂₁₁₂₁ + 8⋅P₂₁₁₁₁⋅T₂₂₂₁₂ + 8⋅P₂₁₁₁₁⋅T₂₂₂₂₁ + 8⋅P₂₁₂₁₁⋅T₂₁
# ₁₁₁ + 2⋅P₂₁₂₁₁⋅T₂₁₁₁₂ + 2⋅P₂₁₂₁₁⋅T₂₁₁₂₁ + 2⋅P₂₁₂₁₁⋅T₂₂₂₁₂ + 2⋅P₂₁₂₁₁⋅T₂₂₂₂₁ +
# 8⋅P₂₁₂₂₂⋅T₂₁₁₁₁ + 2⋅P₂₁₂₂₂⋅T₂₁₁₁₂ + 2⋅P₂₁₂₂₂⋅T₂₁₁₂₁ + 2⋅P₂₁₂₂₂⋅T₂₂₂₁₂ + 2⋅P₂₁₂
# ₂₂⋅T₂₂₂₂₁ + 8⋅P₂₂₁₁₁⋅T₂₁₁₁₁ + 2⋅P₂₂₁₁₁⋅T₂₁₁₁₂ + 2⋅P₂₂₁₁₁⋅T₂₁₁₂₁ + 2⋅P₂₂₁₁₁⋅T₂₂
# ₂₁₂ + 2⋅P₂₂₁₁₁⋅T₂₂₂₂₁ + 8⋅P₂₂₁₂₂⋅T₂₁₁₁₁ + 2⋅P₂₂₁₂₂⋅T₂₁₁₁₂ + 2⋅P₂₂₁₂₂⋅T₂₁₁₂₁ +
# 2⋅P₂₂₁₂₂⋅T₂₂₂₁₂ + 2⋅P₂₂₁₂₂⋅T₂₂₂₂₁ - p₂₂}

# %%
EQS[2,4]
# Out:
# {E₁⋅I₁: 32⋅P₁₁₁₁₁⋅T₁₁₁₁₁ + 8⋅P₁₁₁₁₁⋅T₁₁₁₁₂ + 8⋅P₁₁₁₁₁⋅T₁₁₁₂₁ + 8⋅P₁₁₁₁₁⋅T₁₂₂₁₂
#  + 8⋅P₁₁₁₁₁⋅T₁₂₂₂₁ + 8⋅P₁₁₂₁₁⋅T₁₁₁₁₁ + 2⋅P₁₁₂₁₁⋅T₁₁₁₁₂ + 2⋅P₁₁₂₁₁⋅T₁₁₁₂₁ + 2⋅P
# ₁₁₂₁₁⋅T₁₂₂₁₂ + 2⋅P₁₁₂₁₁⋅T₁₂₂₂₁ + 8⋅P₁₁₂₂₂⋅T₁₁₁₁₁ + 2⋅P₁₁₂₂₂⋅T₁₁₁₁₂ + 2⋅P₁₁₂₂₂⋅
# T₁₁₁₂₁ + 2⋅P₁₁₂₂₂⋅T₁₂₂₁₂ + 2⋅P₁₁₂₂₂⋅T₁₂₂₂₁ + 8⋅P₁₂₁₁₁⋅T₁₁₁₁₁ + 2⋅P₁₂₁₁₁⋅T₁₁₁₁₂
#  + 2⋅P₁₂₁₁₁⋅T₁₁₁₂₁ + 2⋅P₁₂₁₁₁⋅T₁₂₂₁₂ + 2⋅P₁₂₁₁₁⋅T₁₂₂₂₁ + 8⋅P₁₂₁₂₂⋅T₁₁₁₁₁ + 2⋅P
# ₁₂₁₂₂⋅T₁₁₁₁₂ + 2⋅P₁₂₁₂₂⋅T₁₁₁₂₁ + 2⋅P₁₂₁₂₂⋅T₁₂₂₁₂ + 2⋅P₁₂₁₂₂⋅T₁₂₂₂₁ + 32⋅P₂₁₁₁₁
# ⋅T₂₁₁₁₁ + 8⋅P₂₁₁₁₁⋅T₂₁₁₁₂ + 8⋅P₂₁₁₁₁⋅T₂₁₁₂₁ + 8⋅P₂₁₁₁₁⋅T₂₂₂₁₂ + 8⋅P₂₁₁₁₁⋅T₂₂₂₂
# ₁ + 8⋅P₂₁₂₁₁⋅T₂₁₁₁₁ + 2⋅P₂₁₂₁₁⋅T₂₁₁₁₂ + 2⋅P₂₁₂₁₁⋅T₂₁₁₂₁ + 2⋅P₂₁₂₁₁⋅T₂₂₂₁₂ + 2⋅
# P₂₁₂₁₁⋅T₂₂₂₂₁ + 8⋅P₂₁₂₂₂⋅T₂₁₁₁₁ + 2⋅P₂₁₂₂₂⋅T₂₁₁₁₂ + 2⋅P₂₁₂₂₂⋅T₂₁₁₂₁ + 2⋅P₂₁₂₂₂
# ⋅T₂₂₂₁₂ + 2⋅P₂₁₂₂₂⋅T₂₂₂₂₁ + 8⋅P₂₂₁₁₁⋅T₂₁₁₁₁ + 2⋅P₂₂₁₁₁⋅T₂₁₁₁₂ + 2⋅P₂₂₁₁₁⋅T₂₁₁₂
# ₁ + 2⋅P₂₂₁₁₁⋅T₂₂₂₁₂ + 2⋅P₂₂₁₁₁⋅T₂₂₂₂₁ + 8⋅P₂₂₁₂₂⋅T₂₁₁₁₁ + 2⋅P₂₂₁₂₂⋅T₂₁₁₁₂ + 2⋅
# P₂₂₁₂₂⋅T₂₁₁₂₁ + 2⋅P₂₂₁₂₂⋅T₂₂₂₁₂ + 2⋅P₂₂₁₂₂⋅T₂₂₂₂₁ - p₁₁, E₁⋅I₂: 4⋅P₁₁₁₁₁⋅T₁₁₁₁
# ₁ + 4⋅P₁₁₁₁₁⋅T₁₁₁₂₂ + 4⋅P₁₁₁₁₁⋅T₁₁₂₂₂ + 4⋅P₁₁₁₁₁⋅T₁₂₁₂₂ + P₁₁₂₁₁⋅T₁₁₁₁₁ + P₁₁₂
# ₁₁⋅T₁₁₁₂₂ + P₁₁₂₁₁⋅T₁₁₂₂₂ + P₁₁₂₁₁⋅T₁₂₁₂₂ + P₁₁₂₂₂⋅T₁₁₁₁₁ + P₁₁₂₂₂⋅T₁₁₁₂₂ + P₁
# ₁₂₂₂⋅T₁₁₂₂₂ + P₁₁₂₂₂⋅T₁₂₁₂₂ + P₁₂₁₁₁⋅T₁₁₁₁₁ + P₁₂₁₁₁⋅T₁₁₁₂₂ + P₁₂₁₁₁⋅T₁₁₂₂₂ +
# P₁₂₁₁₁⋅T₁₂₁₂₂ + P₁₂₁₂₂⋅T₁₁₁₁₁ + P₁₂₁₂₂⋅T₁₁₁₂₂ + P₁₂₁₂₂⋅T₁₁₂₂₂ + P₁₂₁₂₂⋅T₁₂₁₂₂
# + 4⋅P₂₁₁₁₁⋅T₂₁₁₁₁ + 4⋅P₂₁₁₁₁⋅T₂₁₁₂₂ + 4⋅P₂₁₁₁₁⋅T₂₁₂₂₂ + 4⋅P₂₁₁₁₁⋅T₂₂₁₂₂ + P₂₁₂
# ₁₁⋅T₂₁₁₁₁ + P₂₁₂₁₁⋅T₂₁₁₂₂ + P₂₁₂₁₁⋅T₂₁₂₂₂ + P₂₁₂₁₁⋅T₂₂₁₂₂ + P₂₁₂₂₂⋅T₂₁₁₁₁ + P₂
# ₁₂₂₂⋅T₂₁₁₂₂ + P₂₁₂₂₂⋅T₂₁₂₂₂ + P₂₁₂₂₂⋅T₂₂₁₂₂ + P₂₂₁₁₁⋅T₂₁₁₁₁ + P₂₂₁₁₁⋅T₂₁₁₂₂ +
# P₂₂₁₁₁⋅T₂₁₂₂₂ + P₂₂₁₁₁⋅T₂₂₁₂₂ + P₂₂₁₂₂⋅T₂₁₁₁₁ + P₂₂₁₂₂⋅T₂₁₁₂₂ + P₂₂₁₂₂⋅T₂₁₂₂₂
# + P₂₂₁₂₂⋅T₂₂₁₂₂, E₂⋅I₁: 4⋅P₁₁₁₁₁⋅T₁₁₁₁₁ + P₁₁₁₁₁⋅T₁₁₁₁₂ + P₁₁₁₁₁⋅T₁₁₁₂₁ + P₁₁₁
# ₁₁⋅T₁₂₂₁₂ + P₁₁₁₁₁⋅T₁₂₂₂₁ + 4⋅P₁₂₂₁₁⋅T₁₁₁₁₁ + P₁₂₂₁₁⋅T₁₁₁₁₂ + P₁₂₂₁₁⋅T₁₁₁₂₁ +
# P₁₂₂₁₁⋅T₁₂₂₁₂ + P₁₂₂₁₁⋅T₁₂₂₂₁ + 4⋅P₁₂₂₁₂⋅T₁₁₁₁₁ + P₁₂₂₁₂⋅T₁₁₁₁₂ + P₁₂₂₁₂⋅T₁₁₁₂
# ₁ + P₁₂₂₁₂⋅T₁₂₂₁₂ + P₁₂₂₁₂⋅T₁₂₂₂₁ + 4⋅P₁₂₂₂₁⋅T₁₁₁₁₁ + P₁₂₂₂₁⋅T₁₁₁₁₂ + P₁₂₂₂₁⋅T
# ₁₁₁₂₁ + P₁₂₂₂₁⋅T₁₂₂₁₂ + P₁₂₂₂₁⋅T₁₂₂₂₁ + 4⋅P₂₁₁₁₁⋅T₂₁₁₁₁ + P₂₁₁₁₁⋅T₂₁₁₁₂ + P₂₁₁
# ₁₁⋅T₂₁₁₂₁ + P₂₁₁₁₁⋅T₂₂₂₁₂ + P₂₁₁₁₁⋅T₂₂₂₂₁ + 4⋅P₂₂₂₁₁⋅T₂₁₁₁₁ + P₂₂₂₁₁⋅T₂₁₁₁₂ +
# P₂₂₂₁₁⋅T₂₁₁₂₁ + P₂₂₂₁₁⋅T₂₂₂₁₂ + P₂₂₂₁₁⋅T₂₂₂₂₁ + 4⋅P₂₂₂₁₂⋅T₂₁₁₁₁ + P₂₂₂₁₂⋅T₂₁₁₁
# ₂ + P₂₂₂₁₂⋅T₂₁₁₂₁ + P₂₂₂₁₂⋅T₂₂₂₁₂ + P₂₂₂₁₂⋅T₂₂₂₂₁ + 4⋅P₂₂₂₂₁⋅T₂₁₁₁₁ + P₂₂₂₂₁⋅T
# ₂₁₁₁₂ + P₂₂₂₂₁⋅T₂₁₁₂₁ + P₂₂₂₂₁⋅T₂₂₂₁₂ + P₂₂₂₂₁⋅T₂₂₂₂₁, E₂⋅I₂: 8⋅P₁₁₁₁₁⋅T₁₁₁₁₁
# + 8⋅P₁₁₁₁₁⋅T₁₁₁₂₂ + 8⋅P₁₁₁₁₁⋅T₁₁₂₂₂ + 8⋅P₁₁₁₁₁⋅T₁₂₁₂₂ + 8⋅P₁₂₂₁₁⋅T₁₁₁₁₁ + 8⋅P₁
# ₂₂₁₁⋅T₁₁₁₂₂ + 8⋅P₁₂₂₁₁⋅T₁₁₂₂₂ + 8⋅P₁₂₂₁₁⋅T₁₂₁₂₂ + 8⋅P₁₂₂₁₂⋅T₁₁₁₁₁ + 8⋅P₁₂₂₁₂⋅T
# ₁₁₁₂₂ + 8⋅P₁₂₂₁₂⋅T₁₁₂₂₂ + 8⋅P₁₂₂₁₂⋅T₁₂₁₂₂ + 8⋅P₁₂₂₂₁⋅T₁₁₁₁₁ + 8⋅P₁₂₂₂₁⋅T₁₁₁₂₂
# + 8⋅P₁₂₂₂₁⋅T₁₁₂₂₂ + 8⋅P₁₂₂₂₁⋅T₁₂₁₂₂ + 8⋅P₂₁₁₁₁⋅T₂₁₁₁₁ + 8⋅P₂₁₁₁₁⋅T₂₁₁₂₂ + 8⋅P₂
# ₁₁₁₁⋅T₂₁₂₂₂ + 8⋅P₂₁₁₁₁⋅T₂₂₁₂₂ + 8⋅P₂₂₂₁₁⋅T₂₁₁₁₁ + 8⋅P₂₂₂₁₁⋅T₂₁₁₂₂ + 8⋅P₂₂₂₁₁⋅T
# ₂₁₂₂₂ + 8⋅P₂₂₂₁₁⋅T₂₂₁₂₂ + 8⋅P₂₂₂₁₂⋅T₂₁₁₁₁ + 8⋅P₂₂₂₁₂⋅T₂₁₁₂₂ + 8⋅P₂₂₂₁₂⋅T₂₁₂₂₂
# + 8⋅P₂₂₂₁₂⋅T₂₂₁₂₂ + 8⋅P₂₂₂₂₁⋅T₂₁₁₁₁ + 8⋅P₂₂₂₂₁⋅T₂₁₁₂₂ + 8⋅P₂₂₂₂₁⋅T₂₁₂₂₂ + 8⋅P₂
# ₂₂₂₁⋅T₂₂₁₂₂ - p₂₂}

# %%
alfa = EQS[1,3][ZE[1]*ZE[3]]

# %%
beta = EQS[1,4][ZE[1]*ZE[4]]

# %%
simplify(alfa-8*beta)
# Out:
# -8⋅P₁₁₁₁₁⋅T₁₁₁₂₂ + 8⋅P₁₁₁₁₁⋅T₁₁₂₁₁ - 8⋅P₁₁₁₁₁⋅T₁₁₂₂₂ + 8⋅P₁₁₁₁₁⋅T₁₂₁₁₁ - 8⋅P₁₁
# ₁₁₁⋅T₁₂₁₂₂ + 8⋅P₁₁₁₁₁⋅T₁₂₂₁₁ - 8⋅P₁₁₁₁₂⋅T₁₁₁₂₂ + 8⋅P₁₁₁₁₂⋅T₁₁₂₁₁ - 8⋅P₁₁₁₁₂⋅T₁
# ₁₂₂₂ + 8⋅P₁₁₁₁₂⋅T₁₂₁₁₁ - 8⋅P₁₁₁₁₂⋅T₁₂₁₂₂ + 8⋅P₁₁₁₁₂⋅T₁₂₂₁₁ - 8⋅P₁₁₁₂₁⋅T₁₁₁₂₂ +
#  8⋅P₁₁₁₂₁⋅T₁₁₂₁₁ - 8⋅P₁₁₁₂₁⋅T₁₁₂₂₂ + 8⋅P₁₁₁₂₁⋅T₁₂₁₁₁ - 8⋅P₁₁₁₂₁⋅T₁₂₁₂₂ + 8⋅P₁₁
# ₁₂₁⋅T₁₂₂₁₁ - 8⋅P₁₁₁₂₂⋅T₁₁₁₂₂ + 8⋅P₁₁₁₂₂⋅T₁₁₂₁₁ - 8⋅P₁₁₁₂₂⋅T₁₁₂₂₂ + 8⋅P₁₁₁₂₂⋅T₁
# ₂₁₁₁ - 8⋅P₁₁₁₂₂⋅T₁₂₁₂₂ + 8⋅P₁₁₁₂₂⋅T₁₂₂₁₁ - 8⋅P₂₁₁₁₁⋅T₂₁₁₂₂ + 8⋅P₂₁₁₁₁⋅T₂₁₂₁₁ -
#  8⋅P₂₁₁₁₁⋅T₂₁₂₂₂ + 8⋅P₂₁₁₁₁⋅T₂₂₁₁₁ - 8⋅P₂₁₁₁₁⋅T₂₂₁₂₂ + 8⋅P₂₁₁₁₁⋅T₂₂₂₁₁ - 8⋅P₂₁
# ₁₁₂⋅T₂₁₁₂₂ + 8⋅P₂₁₁₁₂⋅T₂₁₂₁₁ - 8⋅P₂₁₁₁₂⋅T₂₁₂₂₂ + 8⋅P₂₁₁₁₂⋅T₂₂₁₁₁ - 8⋅P₂₁₁₁₂⋅T₂
# ₂₁₂₂ + 8⋅P₂₁₁₁₂⋅T₂₂₂₁₁ - 8⋅P₂₁₁₂₁⋅T₂₁₁₂₂ + 8⋅P₂₁₁₂₁⋅T₂₁₂₁₁ - 8⋅P₂₁₁₂₁⋅T₂₁₂₂₂ +
#  8⋅P₂₁₁₂₁⋅T₂₂₁₁₁ - 8⋅P₂₁₁₂₁⋅T₂₂₁₂₂ + 8⋅P₂₁₁₂₁⋅T₂₂₂₁₁ - 8⋅P₂₁₁₂₂⋅T₂₁₁₂₂ + 8⋅P₂₁
# ₁₂₂⋅T₂₁₂₁₁ - 8⋅P₂₁₁₂₂⋅T₂₁₂₂₂ + 8⋅P₂₁₁₂₂⋅T₂₂₁₁₁ - 8⋅P₂₁₁₂₂⋅T₂₂₁₂₂ + 8⋅P₂₁₁₂₂⋅T₂
# ₂₂₁₁ - p₁₁

# %%
factor(alfa)
# Out:
# 8⋅P₁₁₁₁₁⋅T₁₁₁₁₁ + 8⋅P₁₁₁₁₁⋅T₁₁₂₁₁ + 8⋅P₁₁₁₁₁⋅T₁₂₁₁₁ + 8⋅P₁₁₁₁₁⋅T₁₂₂₁₁ + 8⋅P₁₁₁
# ₁₂⋅T₁₁₁₁₁ + 8⋅P₁₁₁₁₂⋅T₁₁₂₁₁ + 8⋅P₁₁₁₁₂⋅T₁₂₁₁₁ + 8⋅P₁₁₁₁₂⋅T₁₂₂₁₁ + 8⋅P₁₁₁₂₁⋅T₁₁
# ₁₁₁ + 8⋅P₁₁₁₂₁⋅T₁₁₂₁₁ + 8⋅P₁₁₁₂₁⋅T₁₂₁₁₁ + 8⋅P₁₁₁₂₁⋅T₁₂₂₁₁ + 8⋅P₁₁₁₂₂⋅T₁₁₁₁₁ +
# 8⋅P₁₁₁₂₂⋅T₁₁₂₁₁ + 8⋅P₁₁₁₂₂⋅T₁₂₁₁₁ + 8⋅P₁₁₁₂₂⋅T₁₂₂₁₁ + 8⋅P₂₁₁₁₁⋅T₂₁₁₁₁ + 8⋅P₂₁₁
# ₁₁⋅T₂₁₂₁₁ + 8⋅P₂₁₁₁₁⋅T₂₂₁₁₁ + 8⋅P₂₁₁₁₁⋅T₂₂₂₁₁ + 8⋅P₂₁₁₁₂⋅T₂₁₁₁₁ + 8⋅P₂₁₁₁₂⋅T₂₁
# ₂₁₁ + 8⋅P₂₁₁₁₂⋅T₂₂₁₁₁ + 8⋅P₂₁₁₁₂⋅T₂₂₂₁₁ + 8⋅P₂₁₁₂₁⋅T₂₁₁₁₁ + 8⋅P₂₁₁₂₁⋅T₂₁₂₁₁ +
# 8⋅P₂₁₁₂₁⋅T₂₂₁₁₁ + 8⋅P₂₁₁₂₁⋅T₂₂₂₁₁ + 8⋅P₂₁₁₂₂⋅T₂₁₁₁₁ + 8⋅P₂₁₁₂₂⋅T₂₁₂₁₁ + 8⋅P₂₁₁
# ₂₂⋅T₂₂₁₁₁ + 8⋅P₂₁₁₂₂⋅T₂₂₂₁₁ - p₁₁

# %%
factor(beta)
# Out:
# P₁₁₁₁₁⋅T₁₁₁₁₁ + P₁₁₁₁₁⋅T₁₁₁₂₂ + P₁₁₁₁₁⋅T₁₁₂₂₂ + P₁₁₁₁₁⋅T₁₂₁₂₂ + P₁₁₁₁₂⋅T₁₁₁₁₁
# + P₁₁₁₁₂⋅T₁₁₁₂₂ + P₁₁₁₁₂⋅T₁₁₂₂₂ + P₁₁₁₁₂⋅T₁₂₁₂₂ + P₁₁₁₂₁⋅T₁₁₁₁₁ + P₁₁₁₂₁⋅T₁₁₁₂
# ₂ + P₁₁₁₂₁⋅T₁₁₂₂₂ + P₁₁₁₂₁⋅T₁₂₁₂₂ + P₁₁₁₂₂⋅T₁₁₁₁₁ + P₁₁₁₂₂⋅T₁₁₁₂₂ + P₁₁₁₂₂⋅T₁₁
# ₂₂₂ + P₁₁₁₂₂⋅T₁₂₁₂₂ + P₂₁₁₁₁⋅T₂₁₁₁₁ + P₂₁₁₁₁⋅T₂₁₁₂₂ + P₂₁₁₁₁⋅T₂₁₂₂₂ + P₂₁₁₁₁⋅T
# ₂₂₁₂₂ + P₂₁₁₁₂⋅T₂₁₁₁₁ + P₂₁₁₁₂⋅T₂₁₁₂₂ + P₂₁₁₁₂⋅T₂₁₂₂₂ + P₂₁₁₁₂⋅T₂₂₁₂₂ + P₂₁₁₂₁
# ⋅T₂₁₁₁₁ + P₂₁₁₂₁⋅T₂₁₁₂₂ + P₂₁₁₂₁⋅T₂₁₂₂₂ + P₂₁₁₂₁⋅T₂₂₁₂₂ + P₂₁₁₂₂⋅T₂₁₁₁₁ + P₂₁₁
# ₂₂⋅T₂₁₁₂₂ + P₂₁₁₂₂⋅T₂₁₂₂₂ + P₂₁₁₂₂⋅T₂₂₁₂₂

# %%
L0[3]
# Out:
#   2            2            2            2
# I₁ ⋅T₁₁₁₁₁ + I₁ ⋅T₁₁₂₁₁ + I₁ ⋅T₁₂₁₁₁ + I₁ ⋅T₁₂₂₁₁ + 4⋅I₁⋅I₂⋅T₁₁₁₁₁ + I₁⋅I₂⋅T₁₁
#
#                                                      2            2
# ₁₁₂ + I₁⋅I₂⋅T₁₁₁₂₁ + I₁⋅I₂⋅T₁₂₂₁₂ + I₁⋅I₂⋅T₁₂₂₂₁ + I₂ ⋅T₁₁₁₁₁ + I₂ ⋅T₁₁₁₂₂ + I
#
#  2            2
# ₂ ⋅T₁₁₂₂₂ + I₂ ⋅T₁₂₁₂₂
